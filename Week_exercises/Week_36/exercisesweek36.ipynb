# %% [markdown]
# # Exercises week 36
#
# **FYS-STK3155/4155, fall 2026 — deadline Friday September 4 at midnight.**
#
# The aim this week is that you own the two central results of Monday's lecture
# — the statistics of the OLS estimator and the bias-variance decomposition,
# Eq. (2.47) of the book — and the two resampling tools, the bootstrap and
# $k$-fold cross-validation. The code you developed in the Tuesday session
# (`week36tuesday.ipynb`) is meant to be reused here, and everything in this set
# is directly reusable in Project 1.
#
# Reading: Chapter 2, Sections 2.3–2.12 of the book; Hastie et al., Sections
# 7.1–7.5, 7.10 and 7.11.

# %% [markdown]
# ## Exercise 1: Analytical exercises — the statistics of the OLS estimator
#
# Assume the data are generated by the linear model of Eq. (2.37),
# $\boldsymbol{y} = \boldsymbol{X}\boldsymbol{\theta} + \boldsymbol{\varepsilon}$,
# with independent noise $\varepsilon_i \sim \mathcal{N}(0, \sigma^2)$ and a
# fixed (non-stochastic) design matrix $\boldsymbol{X}$ of dimension $n \times p$.
#
# **1a)** Show that the expectation value and variance of a single output are
# (Eq. (2.39))
#
# $$
# \mathbb{E}[y_i] = \boldsymbol{X}_{i,*}\,\boldsymbol{\theta},
# \qquad
# \mathrm{Var}(y_i) = \sigma^2 .
# $$
#
# **1b)** Show that the OLS estimator is unbiased,
# $\mathbb{E}[\hat{\boldsymbol{\theta}}] = \boldsymbol{\theta}$ (Eq. (2.40)), and
# derive its variance (Eq. (2.42)),
#
# $$
# \mathrm{Var}(\hat{\boldsymbol{\theta}}) = \sigma^2\left(\boldsymbol{X}^T\boldsymbol{X}\right)^{-1}.
# $$
#
# *Hint:* use
# $\mathbb{E}[\boldsymbol{y}\boldsymbol{y}^T] = \boldsymbol{X}\boldsymbol{\theta}\boldsymbol{\theta}^T\boldsymbol{X}^T + \sigma^2\boldsymbol{I}_{nn}$.
#
# **1c)** Optional: Explain how the diagonal elements of
# $\sigma^2(\boldsymbol{X}^T\boldsymbol{X})^{-1}$ give a confidence interval for
# the coefficient $\theta_j$ (Eq. (2.43)), and why in practice $\sigma^2$ is
# replaced by
# $\hat{\sigma}^2 = \|\boldsymbol{y}-\boldsymbol{X}\hat{\boldsymbol{\theta}}\|_2^2/(n-p)$.
# Where does the $n-p$ come from? (Think of Bessel's correction, Eq. (2.28).)

# %% [markdown]
# #Exercise 1
#
# # Exercise 1
#
# ## 1a
#
# $X$ is a fixed non-stochastic design matrix. So we can look at $X$ as a constant.
# Also, $\theta$ is a fixed parameter. Therefore,
#
# $$
# X_{i,*}\theta
# $$
#
# is not a stochastic variable, and we can treat it as a constant.
#
# From the linear model,
#
# $$
# y_i = X_{i,*}\theta + \epsilon_i.
# $$
#
# We know that
#
# $$
# \epsilon_i \sim \mathcal{N}(0,\sigma^2),
# $$
#
# so
#
# $$
# E[\epsilon_i] = 0.
# $$
#
# Therefore,
#
# $$
# E[y_i]
# =
# E[X_{i,*}\theta+\epsilon_i].
# $$
#
# Since $X_{i,*}\theta$ is a constant,
#
# $$
# E[y_i]
# =
# X_{i,*}\theta + E[\epsilon_i].
# $$
#
# Since $E[\epsilon_i]=0$, we get
#
# $$
# \boxed{E[y_i]=X_{i,*}\theta}.
# $$
#
# Next step is we want to find the variance of \(y_i\).
#
# As we know we can get that
#
# $$
# y_i = X_{i,*}\theta + \epsilon_i,
# $$
#
# and since \(X_{i,*}\theta\) is a constant,
#
# $$
# Var(y_i)
# =
# Var(X_{i,*}\theta+\epsilon_i)
# =
# Var(\epsilon_i).
# $$
#
# Since
#
# $$
# \epsilon_i \sim \mathcal{N}(0,\sigma^2),
# $$
#
# we get
#
# $$
# \boxed{Var(y_i)=\sigma^2}.
# $$
# #1b
# ## 1b
#
# The OLS estimator is
#
# $$
# \hat{\theta}=(X^TX)^{-1}X^Ty.
# $$
#
# Taking the expectation,
#
# $$
# E[\hat{\theta}]
# =
# E[(X^TX)^{-1}X^Ty].
# $$
#
# Since \(X\) is fixed,
#
# $$
# E[\hat{\theta}]
# =
# (X^TX)^{-1}X^TE[y].
# $$
#
# From the linear model,
#
# $$
# E[y]=X\theta.
# $$
#
# Therefore,
#
# $$
# E[\hat{\theta}]
# =
# (X^TX)^{-1}X^TX\theta.
# $$
#
# Since
#
# $$
# (X^TX)^{-1}(X^TX)=I,
# $$
#
# we obtain
#
# $$
# \boxed{E[\hat{\theta}]=\theta}.
# $$
#
# Therefore, the OLS estimator is unbiased.
# For the variance, we can write
#
# $$
# \hat{\theta}
# =
# (X^TX)^{-1}X^T(X\theta+\epsilon).
# $$
#
# Thus,
#
# $$
# \hat{\theta}
# =
# \theta+(X^TX)^{-1}X^T\epsilon.
# $$
#
# Since \(\theta\) is constant,
#
# $$
# Var(\hat{\theta})
# =
# Var\left((X^TX)^{-1}X^T\epsilon\right).
# $$
#
# Using
#
# $$
# Var(A\epsilon)=A\,Var(\epsilon)\,A^T,
# $$
#
# and
#
# $$
# Var(\epsilon)=\sigma^2 I,
# $$
#
# we get
#
# $$
# Var(\hat{\theta})
# =
# (X^TX)^{-1}X^T
# (\sigma^2I)
# X(X^TX)^{-1}.
# $$
#
# Therefore,
#
# $$
# Var(\hat{\theta})
# =
# \sigma^2
# (X^TX)^{-1}X^TX(X^TX)^{-1}.
# $$
#
# Hence,
#
# $$
# \boxed{
# Var(\hat{\theta})
# =
# \sigma^2(X^TX)^{-1}
# }.
# $$
# #1 c
# ## 1c
#
# From
#
# $$
# Var(\hat{\theta})
# =
# \sigma^2(X^TX)^{-1},
# $$
#
# the variance of coefficient \(\hat{\theta}_j\) is given by the
# \(j\)-th diagonal element,
#
# $$
# Var(\hat{\theta}_j)
# =
# \sigma^2[(X^TX)^{-1}]_{jj}.
# $$
#
# Therefore, its standard error is
#
# $$
# SE(\hat{\theta}_j)
# =
# \sigma\sqrt{[(X^TX)^{-1}]_{jj}}.
# $$
#
# A confidence interval can then be constructed around
# \(\hat{\theta}_j\), for example approximately
#
# $$
# \hat{\theta}_j
# \pm
# 1.96\,SE(\hat{\theta}_j).
# $$
#
#
# In practice, the true noise variance \(\sigma^2\) is unknown, so we estimate it by
#
# $$
# \hat{\sigma}^2
# =
# \frac{\|y-X\hat{\theta}\|_2^2}{n-p}.
# $$
#
# We divide by \(n-p\) because \(p\) parameters are estimated from the data, so \(p\) degrees of freedom are used. Therefore, only \(n-p\) degrees of freedom remain for estimating the noise variance.

# %% [markdown]
# ## Exercise 2: Analytical exercises — deriving the bias-variance tradeoff
#
# Assume now, as in Section 2.10, that the true data are generated by
# $\boldsymbol{y} = f(\boldsymbol{x}) + \boldsymbol{\varepsilon}$ with
# $\boldsymbol{\varepsilon} \sim \mathcal{N}(0, \sigma^2)$ (Eq. (2.44)), and let
# $\tilde{\boldsymbol{y}}$ be the prediction of a model fitted on a randomly
# drawn training set.
#
# **2a)** Starting from the expected squared error
# $\mathbb{E}[(\boldsymbol{y}-\tilde{\boldsymbol{y}})^2]$ and adding and
# subtracting $\mathbb{E}[\tilde{\boldsymbol{y}}]$, derive the decomposition of
# Eq. (2.47),
#
# $$
# \mathbb{E}\left[(\boldsymbol{y}-\tilde{\boldsymbol{y}})^2\right]
# = \frac{1}{n}\sum_i\left(f_i-\mathbb{E}[\tilde{\boldsymbol{y}}]\right)^2
# + \frac{1}{n}\sum_i\left(\tilde{y}_i-\mathbb{E}[\tilde{\boldsymbol{y}}]\right)^2
# + \sigma^2 .
# $$
#
# Show explicitly that all three cross terms vanish, stating for each one which
# assumption kills it (zero-mean noise, independence of noise and training set,
# $f$ non-stochastic).
#
# **2b)** Explain in your own words what the expectation
# $\mathbb{E}[\cdot]$ runs over, and what each of the three terms means for the
# polynomial-fit example of the lecture.
#
# **2c)** In the numerical estimate (Tuesday's Case 1) the bias is computed
# against $y_{\mathrm{test}}$ rather than the unknown $f$. Show that the
# measured "bias" then contains $\sigma^2$, so the printed identity
# `error >= bias + variance` is an inequality.

# %% [markdown]
# #Exercise 2
#
# #2a
#
# #2a
#
# We consider that
#
# $$
# y=f(x)+\epsilon
# $$
#
# so the difference between $y$ and $\hat y$ is
#
# $$
# y-\hat y=f(x)+\epsilon-\hat y.
# $$
#
# Therefore, the expected squared error is
#
# $$
# E[(y-\hat y)^2]
# =
# E[(f(x)+\epsilon-\hat y)^2].
# $$
#
# Now we add and subtract $E[\hat y]$:
#
# $$
# E[(y-\hat y)^2]
# =
# E[(f(x)-E[\hat y]+E[\hat y]-\hat y+\epsilon)^2].
# $$
#
# Expanding the square, we get
#
# $$
# E[(y-\hat y)^2]
# =
# E[(f(x)-E[\hat y])^2]
# +
# E[(E[\hat y]-\hat y)^2]
# +
# E[\epsilon^2]
# $$
#
# $$
# +2E[(f(x)-E[\hat y])(E[\hat y]-\hat y)]
# $$
#
# $$
# +2E[(f(x)-E[\hat y])\epsilon]
# $$
#
# $$
# +2E[(E[\hat y]-\hat y)\epsilon].
# $$
# For the first cross term,
#
# $$
# E[(f(x)-E[\hat y])(E[\hat y]-\hat y)].
# $$
#
# Since $f(x)$ is non-stochastic, $f(x)-E[\hat y]$ can be treated as a constant. Therefore,
#
# $$
# E[(f(x)-E[\hat y])(E[\hat y]-\hat y)]
# $$
#
# $$
# =
# (f(x)-E[\hat y])E[E[\hat y]-\hat y].
# $$
#
# Since
#
# $$
# E[E[\hat y]-\hat y]
# =
# E[\hat y]-E[\hat y]
# =
# 0,
# $$
#
# the first cross term is zero.
#
# For the second cross term,
#
# $$
# E[(f(x)-E[\hat y])\epsilon].
# $$
#
# Since $f(x)$ is non-stochastic,
#
# $$
# E[(f(x)-E[\hat y])\epsilon]
# =
# (f(x)-E[\hat y])E[\epsilon].
# $$
#
# We assume that the noise has zero mean,
#
# $$
# E[\epsilon]=0.
# $$
#
# Therefore,
#
# $$
# E[(f(x)-E[\hat y])\epsilon]=0.
# $$
# Therefore, all three cross terms vanish, and we obtain
#
# $$
# E[(y-\hat y)^2]
# =
# (f(x)-E[\hat y])^2
# +
# E[(\hat y-E[\hat y])^2]
# +
# \sigma^2.
# $$
#
# For the third cross term,
#
# $$
# E[(E[\hat y]-\hat y)\epsilon].
# $$
#
# The noise $\epsilon$ is independent of the training set, and $\hat y$ depends on the training set. Therefore,
#
# $$
# E[(E[\hat y]-\hat y)\epsilon]
# =
# E[E[\hat y]-\hat y]E[\epsilon].
# $$
#
# Since
#
# $$
# E[E[\hat y]-\hat y]=0
# $$
#
# and
#
# $$
# E[\epsilon]=0,
# $$
#
# we get
#
# $$
# E[(E[\hat y]-\hat y)\epsilon]=0.
# $$
#
# Therefore, all three cross terms vanish.
# #2b
# # 2b
#
# The expectation is over the random noise and the randomly drawn training sets.
#
# The squared bias measures how far the average prediction is from the true function $f(x)$.
#
# The variance measures how much the prediction changes when we use different training sets.
#
# The term $\sigma^2$ is the irreducible noise in the data.
# #2c
#
# # 2c
#
# In the numerical estimate, the bias is computed using
#
# $$
# y_{test}=f+\epsilon
# $$
#
# instead of the true function $f$.
#
# Therefore,
#
# $$
# E[(y_{test}-E[\hat y])^2]
# =
# E[(f+\epsilon-E[\hat y])^2].
# $$
#
# Expanding the square gives
#
# $$
# E[(f-E[\hat y])^2]
# +
# E[\epsilon^2]
# +
# 2E[(f-E[\hat y])\epsilon].
# $$
#
# Since
#
# $$
# E[\epsilon]=0
# $$
#
# and
#
# $$
# E[\epsilon^2]=\sigma^2,
# $$
#
# the cross term is zero and we obtain
#
# $$
# E[(y_{test}-E[\hat y])^2]
# =
# (f-E[\hat y])^2+\sigma^2.
# $$
#
# Therefore, the measured bias contains the noise term $\sigma^2$ and is not the true squared bias.
#
# Therefore, the numerical relation is written as
#
# $$
# error \geq bias + variance,
# $$
#
# and the equality holds only in expectation.

# %% [markdown]
# ## Exercise 3: The bias-variance tradeoff with the bootstrap
#
# We use the same data as in the Tuesday session (and as in last week's
# exercise 3),
#
# $$
# y = e^{-x^2} + 1.5\,e^{-(x-2)^2} + \varepsilon,
# \qquad \varepsilon \sim \mathcal{N}(0, 0.1^2),
# $$
#
# on $x \in [-3, 3]$.

# %%
import sys
print(sys.executable)
# Out:
# r:\Miniconda\envs\in4080_2026\python.exe

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.utils import resample

np.random.seed(2026)
n = 40
x = np.linspace(-3, 3, n).reshape(-1, 1)
y = np.exp(-x**2) + 1.5 * np.exp(-(x - 2)**2) + np.random.normal(0, 0.1, x.shape)

# %% [markdown]
# 1. Split the data in training and test parts (80/20). For polynomial degrees
#    $0$ to $13$, use the bootstrap (100 resamples of the training data) to
#    estimate the test error, the squared bias and the variance, and plot the
#    three curves as functions of the degree (compare with
#    `week36_bias_variance.pdf` from the lecture — with seed 2026 you should
#    reproduce it).
# 2. Discuss the figure in terms of Eq. (2.47): where is the model dominated by
#    bias, where by variance, and where would you place the optimal degree?
# 3. Repeat the analysis for $n = 100$ and $n = 400$ data points and comment on
#    how the curves and the optimal degree move.
# 4. Replace OLS by Ridge regression at a fixed high degree (say 12) and study
#    the three terms as functions of $\lambda$ (for example
#    `np.logspace(-6, 2, 9)`). Which term does $\lambda$ attack, and at what
#    cost?

# %%
# Your code for exercise 3 here

#Part 1
#First we change the test parts to 80% and 20%.  This means the size is size = 32 and size = 8
#And we consider the degree of polynomial is from 0 to 13 

#Parameters
n = 40
n_bootstraps = 100
maxdegree = 14

#Test data
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2026)

#Empty arrays
error = np.zeros(maxdegree)
bias = np.zeros(maxdegree)
variance = np.zeros(maxdegree)

#Define the polynomial with degrees 0-13


for degree in range(maxdegree):
    model = make_pipeline(PolynomialFeatures(degree=degree),LinearRegression(fit_intercept=False))
    y_pred = np.empty((y_test.shape[0], n_bootstraps))
    for i in range(n_bootstraps):
        x_, y_ = resample(x_train, y_train) 
        y_pred[:, i] = model.fit(x_, y_).predict(x_test).ravel()
    error[degree] = np.mean(np.mean((y_test - y_pred)**2, axis=1, keepdims=True))
    bias[degree] = np.mean((y_test - np.mean(y_pred, axis=1, keepdims=True))**2)
    variance[degree] = np.mean(np.var(y_pred, axis=1, keepdims=True))



degrees = np.arange(maxdegree)

plt.plot(degrees, error, label="Test error")
plt.plot(degrees, bias, label="Bias squared")
plt.plot(degrees, variance, label="Variance")

plt.xlabel("Polynomial degree")
plt.ylabel("MSE")
plt.yscale("log")

plt.legend()
plt.show()
#Part 2

#Conclusion
#For low polynomial degrees, the test error is mainly dominated by bias. As the degree increases, the variance increases. The optimal degree is around 5, where the test error is smallest.

#Part 3

#For n = 100 and n = 400
#Parameters
n = 100
np.random.seed(2026)
n_bootstraps = 100
maxdegree = 14
x = np.linspace(-3, 3, n).reshape(-1, 1)
y = np.exp(-x**2) + 1.5 * np.exp(-(x - 2)**2) + np.random.normal(0, 0.1, x.shape)
#Test data
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2026)

#Empty arrays
error = np.zeros(maxdegree)
bias = np.zeros(maxdegree)
variance = np.zeros(maxdegree)

#Define the polynomial with degrees 0-13


for degree in range(maxdegree):
    model = make_pipeline(PolynomialFeatures(degree=degree),LinearRegression(fit_intercept=False))
    y_pred = np.empty((y_test.shape[0], n_bootstraps))
    for i in range(n_bootstraps):
        x_, y_ = resample(x_train, y_train) 
        y_pred[:, i] = model.fit(x_, y_).predict(x_test).ravel()
    error[degree] = np.mean(np.mean((y_test - y_pred)**2, axis=1, keepdims=True))
    bias[degree] = np.mean((y_test - np.mean(y_pred, axis=1, keepdims=True))**2)
    variance[degree] = np.mean(np.var(y_pred, axis=1, keepdims=True))


degrees = np.arange(maxdegree)

plt.plot(degrees, error, label="Test error")
plt.plot(degrees, bias, label="Bias squared")
plt.plot(degrees, variance, label="Variance")

plt.xlabel("Polynomial degree")
plt.ylabel("MSE")
plt.yscale("log")

plt.legend()
plt.show()

#n = 400
#Parameters
n = 400
np.random.seed(2026)
n_bootstraps = 100
maxdegree = 14
x = np.linspace(-3, 3, n).reshape(-1, 1)
y = np.exp(-x**2) + 1.5 * np.exp(-(x - 2)**2) + np.random.normal(0, 0.1, x.shape)
#Test data
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2026)

#Empty arrays
error = np.zeros(maxdegree)
bias = np.zeros(maxdegree)
variance = np.zeros(maxdegree)

#Define the polynomial with degrees 0-13


for degree in range(maxdegree):
    model = make_pipeline(PolynomialFeatures(degree=degree),LinearRegression(fit_intercept=False))
    y_pred = np.empty((y_test.shape[0], n_bootstraps))
    for i in range(n_bootstraps):
        x_, y_ = resample(x_train, y_train) 
        y_pred[:, i] = model.fit(x_, y_).predict(x_test).ravel()
    error[degree] = np.mean(np.mean((y_test - y_pred)**2, axis=1, keepdims=True))
    bias[degree] = np.mean((y_test - np.mean(y_pred, axis=1, keepdims=True))**2)
    variance[degree] = np.mean(np.var(y_pred, axis=1, keepdims=True))



degrees = np.arange(maxdegree)

plt.plot(degrees, error, label="Test error")
plt.plot(degrees, bias, label="Bias squared")
plt.plot(degrees, variance, label="Variance")

plt.xlabel("Polynomial degree")
plt.ylabel("MSE")
plt.yscale("log")

plt.legend()
plt.show()

#Conclusion
#  As the number of data points increases from \(n=100\) to \(n=400\), the variance becomes much smaller and the optimal polynomial degree moves to a higher value.


#Part 4

np.random.seed(2026)
n = 40
x = np.linspace(-3, 3, n).reshape(-1, 1)
y = np.exp(-x**2) + 1.5 * np.exp(-(x - 2)**2) + np.random.normal(0, 0.1, x.shape)
#Test data
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2026)


#Different lambda values


lambdas = np.logspace(-6,2,9)

error = np.zeros(len(lambdas))
bias = np.zeros(len(lambdas))
variance = np.zeros(len(lambdas))

for j,lmb in enumerate(lambdas):
    model = make_pipeline(PolynomialFeatures(degree=degree),StandardScaler(),Ridge(alpha=lmb))
    y_pred = np.empty((y_test.shape[0], n_bootstraps))
    for i in range(n_bootstraps):
        x_, y_ = resample(x_train, y_train) 
        y_pred[:, i] = model.fit(x_, y_).predict(x_test).ravel()


    error[j] = np.mean(np.mean((y_test - y_pred)**2, axis=1, keepdims=True))
    bias[j] = np.mean((y_test - np.mean(y_pred, axis=1, keepdims=True))**2)
    variance[j] = np.mean(np.var(y_pred, axis=1, keepdims=True))


plt.plot(lambdas,error,label= "Test error")
plt.plot(lambdas,bias,label = "Bias squared")
plt.plot(lambdas,variance,label= "Variance")
plt.xscale("log")
plt.xlabel("Lambda")
plt.ylabel("MSE")
plt.legend()
plt.show()

#Conclusion
#As lambda increases, Ridge reduces the variance, but a large lambda increases the bias; the lowest test error is around lambda = 10^-2.

# %% [markdown]
# ## Exercise 4: Cross-validation
#
# Still with the same type of data, we now select models without consuming a
# test set.
#
# 1. Use scikit-learn's (or perhaps write your own) $k$-fold cross-validation function: shuffle the data,
#    split into $k$ folds, use each fold as test set once, and return the mean
#    and standard deviation over folds of the test MSE. Do **not** use
#    `cross_val_score` inside your own function.
# 2. Use it with $k = 5$ to compute the CV estimate of the MSE for OLS with
#    polynomial degrees $0$ to $13$, and compare with the bootstrap analysis of
#    exercise 3: do the two methods point to the same degree window?
# 3. For a degree-6 polynomial with Ridge regression on
#    $y = 3x^2 + \varepsilon$, $\varepsilon \sim \mathcal{N}(0,1)$, $n=100$
#    (Tuesday's Case 2), compute the CV MSE on
#    `np.logspace(-3, 5, 100)` and find the optimal $\lambda$. Any
#    scaling/preprocessing must be fitted **inside** each fold — explain in one
#    or two sentences why.
# 4. Try $k = 5, 10$ and $n$ (leave-one-out). Comment on the stability of the
#    selected $\lambda$ and on the computational cost.

# %%
# Your code for exercise 4 here

np.random.seed(2026)
n = 40
x = np.linspace(-3, 3, n).reshape(-1, 1)
y = np.exp(-x**2) + 1.5 * np.exp(-(x - 2)**2) + np.random.normal(0, 0.1, x.shape)


#Part 1
kFold = KFold(n_splits=5,shuffle=True,random_state =2026)



def k_fold_cv(x, y, degree, k=5):
    kFold = KFold(n_splits=5,shuffle=True,random_state =2026)

    mse_values = []

    for train_index, test_index in kFold.split(x):

        x_train = x[train_index]
        x_test = x[test_index]

        y_train = y[train_index]
        y_test = y[test_index]

        # Define model
        model = make_pipeline(PolynomialFeatures(degree=degree),LinearRegression(fit_intercept=False))

        # Fit and predict
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)

        # MSE for this fold
        mse = np.mean((y_test - y_pred)**2)

        # Save this fold's MSE
        mse_values.append(mse)

    # Mean and standard deviation over all folds
    return np.mean(mse_values), np.std(mse_values)


#Part 2


degrees = np.arange(14)

cv_mean = np.zeros(14)
cv_std =np.zeros(14)

for degree in degrees:
    cv_mean[degree],cv_std[degree]=k_fold_cv(x,y,degree,k=5)


best_degree= np.argmin(cv_mean)


print("Best degree",best_degree)
print("Minimum CV MSE",cv_mean[best_degree])


plt.plot(degrees,cv_mean)
plt.xlabel("Polynomial degree")
plt.ylabel("CV MSE")
plt.show()

#Part 3

#Define the data


rng = np.random.default_rng(2026)

x = rng.standard_normal(100)
y = 3*x**2 + rng.standard_normal(100)

lambdas =np.logspace(-3,5,100)

kFold = KFold(n_splits=5,shuffle=True,random_state=2026)


poly = PolynomialFeatures(degree=6)

score_Kfold = np.zeros((len(lambdas), 5))


for i,lmb  in enumerate(lambdas):
    for j, (train_inds, test_inds) in enumerate(kFold.split(x)):
        Xtrain = poly.fit_transform(x[train_inds][:,np.newaxis])
        Xtest =  poly.fit_transform(x[test_inds][:,np.newaxis])
          # Scaling fitted only on training fold
        scaler = StandardScaler().fit(Xtrain)

        Xtrain_scaled = scaler.transform(Xtrain)
        Xtest_scaled = scaler.transform(Xtest)

        # Ridge
        ridge = Ridge(alpha=lmb)

        ridge.fit(Xtrain_scaled,y[train_inds])

        y_pred = ridge.predict(Xtest_scaled)

        # MSE
        score_Kfold[i, j] = np.mean((y_pred - y[test_inds])**2)


# Mean CV MSE for each lambda
cv_mean = np.mean(score_Kfold, axis=1)

# Find optimal lambda
best_index = np.argmin(cv_mean)
best_lambda = lambdas[best_index]

print("Optimal lambda:", best_lambda)
print("Minimum CV MSE:", cv_mean[best_index])


# Plot

plt.plot(lambdas, cv_mean)

plt.xscale("log")

plt.xlabel("Lambda")
plt.ylabel("CV MSE")

plt.show()

#Conclusion
#The optimal lambda is approximately 1.18, with a minimum CV MSE of about 1.46.
#The scaler must be fitted only on the training fold to avoid data leakage from the test fold.


#Part 4

# We assume k equal 5 10 100

for k in [5,10,100]:
    kFold = KFold(n_splits=k,shuffle=True,random_state=2026)
    scores = np.zeros((len(lambdas),k))
    for  i , lmb in enumerate(lambdas):
        for j, (train_inds, test_inds) in enumerate(kFold.split(x)):
            
            Xtrain = poly.fit_transform(x[train_inds][:,np.newaxis])
            Xtest = poly.transform(x[test_inds][:,np.newaxis])
          # Scaling fitted only on training fold
            scaler = StandardScaler().fit(Xtrain)

            Xtrain_scaled = scaler.transform(Xtrain)
            Xtest_scaled = scaler.transform(Xtest)

        # Ridge
            ridge = Ridge(alpha=lmb)

            ridge.fit(Xtrain_scaled,y[train_inds])

            y_pred = ridge.predict(Xtest_scaled)

        # MSE
            scores[i, j]  = np.mean((y_pred - y[test_inds])**2)



    # Mean CV MSE for each lambda
    cv_mean = np.mean(scores, axis=1)

    # Find optimal lambda
    best_index = np.argmin(cv_mean)
    best_lambda = lambdas[best_index]

    print("k =", k)
    print("Optimal lambda:", best_lambda)
    print("Minimum CV MSE:", cv_mean[best_index])
    print()

# Conclusion

# The optimal lambda changes only slightly when k increases, and the CV MSE stays almost the same.
# Out:
# Best degree 9
# Minimum CV MSE 0.019757412028533844
# Optimal lambda: 1.1768119524349991
# Minimum CV MSE: 1.4569405421390536
# k = 5
# Optimal lambda: 1.1768119524349991
# Minimum CV MSE: 1.4569405421390536
#
# k = 10
# Optimal lambda: 2.0565123083486534
# Minimum CV MSE: 1.470824686598049
#
# k = 100
# Optimal lambda: 2.4770763559917115
# Minimum CV MSE: 1.4435393819932743

# %% [markdown]
# ## Exercise 5 (optional): error bars from the bootstrap
#
# Use the bootstrap to attach uncertainties to fitted parameters, where the
# analytical formula of exercise 1 can be checked — and where it cannot.
#
# 1. For OLS on a degree-3 polynomial fit of the exercise-3 data, bootstrap the
#    training data 1000 times and histogram the resulting
#    $\hat{\theta}_j^*$. Compare the bootstrap standard deviations with the
#    analytical standard errors
#    $\hat{\sigma}\sqrt{[(\boldsymbol{X}^T\boldsymbol{X})^{-1}]_{jj}}$ of
#    Eq. (2.43).
# 2. Repeat for Lasso with a small penalty. Why is the bootstrap now the only
#    option on the table? (Which assumption behind Eq. (2.43) fails?)

# %%
# Your code for exercise 5 here

#Use the data from exercise 3.

degree = 3
n_bootstraps = 1000

poly = PolynomialFeatures(degree=3)

X_train = poly.fit_transform(x_train)

theta_bootstrap = np.zeros((n_bootstraps, 4))

for i in range (n_bootstraps):
    x_,y_ = resample(x_train,y_train)

    X_ = poly.fit_transform(x_)
    model = LinearRegression (fit_intercept= False)
    model.fit(X_,y_)

    theta_bootstrap[i, :] = model.coef_.ravel()
    bootstrap_std = np.std(theta_bootstrap,axis =0)
    print("Bootstrap standard deviatation")
    print(bootstrap_std)
# Out:
# Bootstrap standard deviatation
# [0.0247942  0.01257253 0.00083416 0.00067254]
# Bootstrap standard deviatation
# [0.03687561 0.01890996 0.00200122 0.00129923]
# Bootstrap standard deviatation
# [0.04337971 0.0224097  0.0022897  0.0015356 ]
# Bootstrap standard deviatation
# [0.05200183 0.02553727 0.00293739 0.00172925]
# Bootstrap standard deviatation
# [0.05756781 0.02881955 0.00323647 0.0019811 ]
# Bootstrap standard deviatation
# [0.06148868 0.03219598 0.00331671 0.00237116]
# Bootstrap standard deviatation
# [0.06755566 0.03544457 0.00391648 0.00264902]
# Bootstrap standard deviatation
# [0.07166275 0.03800908 0.00411361 0.00286936]
# Bootstrap standard deviatation
# [0.07583872 0.03933288 0.00434294 0.00292602]
# Bootstrap standard deviatation
# [0.08066451 0.04062636 0.00467581 0.00296858]
# Bootstrap standard deviatation
# [0.08431745 0.04338642 0.0048959  0.00325979]
# Bootstrap standard deviatation
# [0.08851666 0.04610568 0.00522415 0.00355369]
# Bootstrap standard deviatation
# [0.09277975 0.04725589 0.00566853 0.00362531]
# Bootstrap standard deviatation
# [0.09651467 0.04967455 0.00593063 0.00387878]
# Bootstrap standard deviatation
# [0.09960609 0.05169179 0.00610996 0.00406962]
# Bootstrap standard deviatation
# [0.10254108 0.05306033 0.00637979 0.00415636]
# Bootstrap standard deviatation
# [0.10517436 0.05543198 0.00642387 0.00441247]
# Bootstrap standard deviatation
# [0.10769013 0.05703356 0.00657391 0.00454285]
# Bootstrap standard deviatation
# [0.1110248  0.05832426 0.00679231 0.00461862]
# Bootstrap standard deviatation
# [0.11395918 0.05981274 0.00696783 0.00472779]
# Bootstrap standard deviatation
# [0.1171027  0.06162068 0.00723088 0.00488593]
# Bootstrap standard deviatation
# [0.11995056 0.06284778 0.00745037 0.00495972]
# Bootstrap standard deviatation
# [0.12297419 0.06394319 0.00773042 0.00504708]
# Bootstrap standard deviatation
# [0.12518496 0.06549404 0.00785999 0.0051817 ]
# Bootstrap standard deviatation
# [0.12781044 0.06724316 0.00805589 0.00535366]
# Bootstrap standard deviatation
# [0.13004726 0.06832468 0.00820289 0.0054313 ]
# Bootstrap standard deviatation
# [0.13266283 0.07002462 0.00837738 0.00558605]
# Bootstrap standard deviatation
# [0.13482338 0.07151425 0.00846024 0.00570058]
# Bootstrap standard deviatation
# [0.13720228 0.07252555 0.00859725 0.00576203]
# Bootstrap standard deviatation
# [0.13981787 0.07438026 0.00882178 0.00595459]
# Bootstrap standard deviatation
# [0.14154828 0.075471   0.00887999 0.00602497]
# Bootstrap standard deviatation
# [0.1439108  0.07650388 0.00902809 0.0060934 ]
# Bootstrap standard deviatation
# [0.14534483 0.07755529 0.00904122 0.00616214]
# Bootstrap standard deviatation
# [0.1471104  0.07876971 0.00908398 0.0062362 ]
# Bootstrap standard deviatation
# [0.14944762 0.07985118 0.00923788 0.00631275]
# Bootstrap standard deviatation
# [0.15153824 0.08040027 0.00944589 0.00634249]
# Bootstrap standard deviatation
# [0.15336112 0.08148049 0.00955414 0.00643601]
# Bootstrap standard deviatation
# [0.15537446 0.08319322 0.00967361 0.00661946]
# Bootstrap standard deviatation
# [0.157115   0.08386575 0.0097971  0.00667151]
# Bootstrap standard deviatation
# [0.15906959 0.08442675 0.00992144 0.00670027]
# Bootstrap standard deviatation
# [0.16159853 0.08558737 0.01016563 0.00680599]
# Bootstrap standard deviatation
# [0.16392593 0.08696603 0.01036313 0.00693411]
# Bootstrap standard deviatation
# [0.16592342 0.0882229  0.01050176 0.00706819]
# Bootstrap standard deviatation
# [0.16758564 0.08922868 0.01055048 0.00712905]
# Bootstrap standard deviatation
# [0.16949653 0.09022513 0.01066601 0.00721023]
# Bootstrap standard deviatation
# [0.17165997 0.09096382 0.01089206 0.0072504 ]
# Bootstrap standard deviatation
# [0.17339035 0.09167898 0.01101156 0.00729298]
# Bootstrap standard deviatation
# [0.17502586 0.09257468 0.01110518 0.00736524]
# Bootstrap standard deviatation
# [0.17630345 0.09337353 0.01111832 0.00740111]
# Bootstrap standard deviatation
# [0.17815899 0.09428078 0.01127378 0.00747021]
# Bootstrap standard deviatation
# [0.180194   0.09523212 0.01143574 0.00754445]
# Bootstrap standard deviatation
# [0.18224934 0.09671814 0.01160636 0.0077069 ]
# Bootstrap standard deviatation
# [0.18396384 0.09721044 0.01174393 0.00773394]
# Bootstrap standard deviatation
# [0.18530717 0.09800233 0.01180263 0.00779403]
# Bootstrap standard deviatation
# [0.18687638 0.09955585 0.01185022 0.0079813 ]
# Bootstrap standard deviatation
# [0.18806902 0.10042045 0.01190372 0.00806171]
# Bootstrap standard deviatation
# [0.18948666 0.10144634 0.01196029 0.00815037]
# Bootstrap standard deviatation
# [0.19109975 0.10204148 0.01208352 0.00818023]
# Bootstrap standard deviatation
# [0.19325398 0.10276547 0.01230354 0.00824083]
# Bootstrap standard deviatation
# [0.1947579  0.10353582 0.01237413 0.00829269]
# Bootstrap standard deviatation
# [0.19630854 0.10439541 0.01245271 0.0083632 ]
# Bootstrap standard deviatation
# [0.19743395 0.10497213 0.01246338 0.00838045]
# Bootstrap standard deviatation
# [0.19861698 0.10566436 0.01254116 0.00843671]
# Bootstrap standard deviatation
# [0.20051847 0.1066237  0.01270517 0.00852984]
# Bootstrap standard deviatation
# [0.20233666 0.1077613  0.01281522 0.00865412]
# Bootstrap standard deviatation
# [0.20347517 0.10841402 0.01286263 0.00869435]
# Bootstrap standard deviatation
# [0.2049276  0.10951566 0.01296144 0.0088189 ]
# Bootstrap standard deviatation
# [0.20650821 0.11041909 0.01305517 0.00888712]
# Bootstrap standard deviatation
# [0.20807674 0.11140774 0.01316751 0.0089789 ]
# Bootstrap standard deviatation
# [0.20960092 0.11231699 0.01329827 0.00906834]
# Bootstrap standard deviatation
# [0.21070122 0.11299469 0.01333642 0.00911873]
# Bootstrap standard deviatation
# [0.2122438  0.11414877 0.0134355  0.00923518]
# Bootstrap standard deviatation
# [0.2138266  0.11518311 0.01357614 0.00933772]
# Bootstrap standard deviatation
# [0.21530433 0.11593336 0.01365685 0.00939135]
# Bootstrap standard deviatation
# [0.21658436 0.11656969 0.01370599 0.00943432]
# Bootstrap standard deviatation
# [0.21766025 0.11715119 0.0137559  0.00947544]
# Bootstrap standard deviatation
# [0.21874968 0.11785687 0.01381979 0.00953461]
# Bootstrap standard deviatation
# [0.22023292 0.11871262 0.01393067 0.00961589]
# Bootstrap standard deviatation
# [0.22111835 0.1196188  0.0139495  0.00971451]
# Bootstrap standard deviatation
# [0.22219481 0.12013704 0.01398193 0.00974172]
# Bootstrap standard deviatation
# [0.22369413 0.12067564 0.01412627 0.00977567]
# Bootstrap standard deviatation
# [0.2247535  0.12138954 0.01418882 0.00984579]
# Bootstrap standard deviatation
# [0.22557948 0.12194664 0.01418982 0.00986153]
# Bootstrap standard deviatation
# [0.22709292 0.12281564 0.01430739 0.00994618]
# Bootstrap standard deviatation
# [0.22844045 0.12357841 0.0144292  0.01001694]
# Bootstrap standard deviatation
# [0.2296005  0.12428769 0.01450644 0.01007608]
# Bootstrap standard deviatation
# [0.23089043 0.1247004  0.01460273 0.01010304]
# Bootstrap standard deviatation
# [0.23254095 0.12536584 0.01474795 0.01016282]
# Bootstrap standard deviatation
# [0.23363589 0.12586637 0.01479457 0.01019287]
# Bootstrap standard deviatation
# [0.23508042 0.12661301 0.01491171 0.01025885]
# Bootstrap standard deviatation
# [0.23626993 0.12730068 0.01498485 0.01032258]
# Bootstrap standard deviatation
# [0.23718497 0.12777711 0.01504072 0.0103587 ]
# Bootstrap standard deviatation
# [0.23818562 0.12811415 0.01510549 0.01037396]
# Bootstrap standard deviatation
# [0.23930791 0.12854187 0.01519523 0.01040492]
# Bootstrap standard deviatation
# [0.24075579 0.12887223 0.01535359 0.0104275 ]
# Bootstrap standard deviatation
# [0.24206174 0.12923704 0.01546208 0.01044964]
# Bootstrap standard deviatation
# [0.2431671  0.12964042 0.01552819 0.0104733 ]
# Bootstrap standard deviatation
# [0.24462024 0.13069792 0.01563483 0.01058816]
# Bootstrap standard deviatation
# [0.24545531 0.1312054  0.01567459 0.01063218]
# Bootstrap standard deviatation
# [0.24661432 0.13182779 0.01575271 0.01069127]
# Bootstrap standard deviatation
# [0.24757948 0.13226448 0.01579684 0.01071299]
# Bootstrap standard deviatation
# [0.24841449 0.13267126 0.01580963 0.01072946]
# Bootstrap standard deviatation
# [0.24925551 0.13330168 0.01584506 0.01078844]
# Bootstrap standard deviatation
# [0.25075345 0.1337822  0.0160434  0.01083122]
# Bootstrap standard deviatation
# [0.2519357  0.13442178 0.01612498 0.01088598]
# Bootstrap standard deviatation
# [0.25318451 0.13488646 0.01621106 0.01091916]
# Bootstrap standard deviatation
# [0.25398327 0.13530107 0.01625057 0.01094899]
# Bootstrap standard deviatation
# [0.25505299 0.13575944 0.01632952 0.01098625]
# Bootstrap standard deviatation
# [0.25595854 0.1363095  0.01637503 0.01102833]
# Bootstrap standard deviatation
# [0.25702725 0.13689562 0.01641688 0.01106719]
# Bootstrap standard deviatation
# [0.25815076 0.13774878 0.01650183 0.01115935]
# Bootstrap standard deviatation
# [0.25923372 0.13828083 0.01658279 0.01119978]
# Bootstrap standard deviatation
# [0.26038821 0.13875906 0.01665882 0.01123412]
# Bootstrap standard deviatation
# [0.26150397 0.1394811  0.01674729 0.01130565]
# Bootstrap standard deviatation
# [0.26263676 0.14008884 0.01683264 0.0113448 ]
# Bootstrap standard deviatation
# [0.26347886 0.14045891 0.01686628 0.0113631 ]
# Bootstrap standard deviatation
# [0.26437695 0.14087767 0.01691015 0.01138911]
# Bootstrap standard deviatation
# [0.26553625 0.14138385 0.01699182 0.01142537]
# Bootstrap standard deviatation
# [0.26638039 0.14175957 0.01706363 0.01144258]
# Bootstrap standard deviatation
# [0.26729066 0.1423058  0.01711945 0.01149554]
# Bootstrap standard deviatation
# [0.26806564 0.14270421 0.01716832 0.0115289 ]
# Bootstrap standard deviatation
# [0.26903916 0.14307981 0.01723666 0.0115507 ]
# Bootstrap standard deviatation
# [0.26964836 0.14351595 0.01724182 0.01157427]
# Bootstrap standard deviatation
# [0.27045102 0.14398003 0.017277   0.01161416]
# Bootstrap standard deviatation
# [0.27139375 0.14456432 0.01731962 0.0116592 ]
# Bootstrap standard deviatation
# [0.27249925 0.1451899  0.01741373 0.01171353]
# Bootstrap standard deviatation
# [0.27367315 0.14586585 0.01750228 0.01177708]
# Bootstrap standard deviatation
# [0.27464479 0.14651838 0.01757726 0.01183834]
# Bootstrap standard deviatation
# [0.27546803 0.14683914 0.01765387 0.01186057]
# Bootstrap standard deviatation
# [0.27647561 0.14729511 0.017725   0.01189666]
# Bootstrap standard deviatation
# [0.2773812  0.14776695 0.01777835 0.01193492]
# Bootstrap standard deviatation
# [0.27827632 0.14801292 0.01780676 0.01193939]
# Bootstrap standard deviatation
# [0.27918675 0.14860066 0.01786636 0.01199624]
# Bootstrap standard deviatation
# [0.28010753 0.14874635 0.01789759 0.0119995 ]
# Bootstrap standard deviatation
# [0.28080832 0.14895249 0.0179313  0.01200862]
# Bootstrap standard deviatation
# [0.28183262 0.14936381 0.01800559 0.01203433]
# Bootstrap standard deviatation
# [0.28263106 0.14981713 0.01805589 0.01206828]
# Bootstrap standard deviatation
# [0.2834432  0.15011514 0.01810422 0.01208439]
# Bootstrap standard deviatation
# [0.28435688 0.15062051 0.01816427 0.01212222]
# Bootstrap standard deviatation
# [0.28522253 0.15108354 0.01822413 0.01215483]
# Bootstrap standard deviatation
# [0.28613756 0.15159114 0.01828493 0.01219685]
# Bootstrap standard deviatation
# [0.28725713 0.15226371 0.01839001 0.0122653 ]
# Bootstrap standard deviatation
# [0.28808123 0.15271279 0.01844122 0.01230239]
# Bootstrap standard deviatation
# [0.28880303 0.15318675 0.01847827 0.01234346]
# Bootstrap standard deviatation
# [0.28944076 0.15359477 0.01849294 0.01236582]
# Bootstrap standard deviatation
# [0.29026562 0.15424737 0.0185289  0.01242523]
# Bootstrap standard deviatation
# [0.29118074 0.15465684 0.01860257 0.01245226]
# Bootstrap standard deviatation
# [0.29209984 0.15508634 0.01868663 0.01249129]
# Bootstrap standard deviatation
# [0.2930009  0.15548396 0.01875969 0.01252373]
# Bootstrap standard deviatation
# [0.29357515 0.15580133 0.01875929 0.01252565]
# Bootstrap standard deviatation
# [0.29425279 0.15623472 0.01879353 0.01255734]
# Bootstrap standard deviatation
# [0.2950056  0.15663005 0.01883917 0.01258776]
# Bootstrap standard deviatation
# [0.29573414 0.15704455 0.01888764 0.01261945]
# Bootstrap standard deviatation
# [0.29642978 0.15726371 0.01895473 0.01263315]
# Bootstrap standard deviatation
# [0.29715344 0.15760768 0.01899314 0.0126528 ]
# Bootstrap standard deviatation
# [0.29788749 0.15795242 0.01904993 0.0126797 ]
# Bootstrap standard deviatation
# [0.2989055  0.15842738 0.01912639 0.01272306]
# Bootstrap standard deviatation
# [0.29968226 0.15879479 0.01916406 0.01274558]
# Bootstrap standard deviatation
# [0.30012712 0.15917003 0.01916857 0.0127777 ]
# Bootstrap standard deviatation
# [0.30120421 0.15963882 0.01928972 0.01281677]
# Bootstrap standard deviatation
# [0.30212357 0.1599852  0.01933991 0.01283775]
# Bootstrap standard deviatation
# [0.30286764 0.16049566 0.01939991 0.01287908]
# Bootstrap standard deviatation
# [0.30357107 0.16083661 0.01946156 0.01290643]
# Bootstrap standard deviatation
# [0.30427053 0.16128778 0.01949478 0.01294506]
# Bootstrap standard deviatation
# [0.30479783 0.16159418 0.01952014 0.01296721]
# Bootstrap standard deviatation
# [0.30540015 0.16201782 0.01954668 0.01299985]
# Bootstrap standard deviatation
# [0.30601909 0.16232851 0.0195773  0.01301912]
# Bootstrap standard deviatation
# [0.30659747 0.16269597 0.01961017 0.01304751]
# Bootstrap standard deviatation
# [0.30733007 0.16292497 0.0196429  0.0130574 ]
# Bootstrap standard deviatation
# [0.30835837 0.16320462 0.01975754 0.0130791 ]
# Bootstrap standard deviatation
# [0.30910307 0.16342062 0.01979166 0.01308503]
# Bootstrap standard deviatation
# [0.30982478 0.16367125 0.01984018 0.01309597]
# Bootstrap standard deviatation
# [0.31046873 0.16395459 0.01987054 0.01311211]
# Bootstrap standard deviatation
# [0.31116533 0.16445283 0.01992603 0.01315544]
# Bootstrap standard deviatation
# [0.31173882 0.16482434 0.01993971 0.01317516]
# Bootstrap standard deviatation
# [0.31275034 0.16527071 0.0200616  0.01321361]
# Bootstrap standard deviatation
# [0.31340032 0.16562878 0.02006937 0.01322734]
# Bootstrap standard deviatation
# [0.3144075  0.16608619 0.02016055 0.01326338]
# Bootstrap standard deviatation
# [0.31510085 0.16628292 0.02022429 0.0132691 ]
# Bootstrap standard deviatation
# [0.31609881 0.16674842 0.0203448  0.01331232]
# Bootstrap standard deviatation
# [0.31716884 0.1673838  0.0204561  0.01338262]
# Bootstrap standard deviatation
# [0.3180168  0.16772006 0.02054139 0.01340851]
# Bootstrap standard deviatation
# [0.31867638 0.16804059 0.02056896 0.01342552]
# Bootstrap standard deviatation
# [0.31937319 0.16828932 0.02060877 0.01344027]
# Bootstrap standard deviatation
# [0.31990442 0.16874896 0.02063802 0.01348492]
# Bootstrap standard deviatation
# [0.32051633 0.16920932 0.02067594 0.01353917]
# Bootstrap standard deviatation
# [0.32119925 0.16962432 0.02072256 0.01357383]
# Bootstrap standard deviatation
# [0.32177038 0.16991626 0.02073834 0.01359013]
# Bootstrap standard deviatation
# [0.32230125 0.17017835 0.02076834 0.01361123]
# Bootstrap standard deviatation
# [0.32301281 0.17046249 0.02082311 0.01362881]
# Bootstrap standard deviatation
# [0.32377166 0.17085373 0.02087997 0.01366574]
# Bootstrap standard deviatation
# [0.3244369  0.1711368  0.02096249 0.01368312]
# Bootstrap standard deviatation
# [0.3249818  0.17147288 0.0209922  0.01371098]
# Bootstrap standard deviatation
# [0.32573343 0.17167212 0.02102882 0.01371881]
# Bootstrap standard deviatation
# [0.32609612 0.17200006 0.02102655 0.01373086]
# Bootstrap standard deviatation
# [0.32663074 0.17225143 0.02104386 0.01374497]
# Bootstrap standard deviatation
# [0.32712504 0.17264423 0.02104882 0.01377486]
# Bootstrap standard deviatation
# [0.32770689 0.17294427 0.02108944 0.01379888]
# Bootstrap standard deviatation
# [0.32824422 0.17322878 0.02111764 0.01381681]
# Bootstrap standard deviatation
# [0.32910985 0.17381499 0.0211781  0.01389323]
# Bootstrap standard deviatation
# [0.32974298 0.17422642 0.02122638 0.01393424]
# Bootstrap standard deviatation
# [0.33035429 0.17445365 0.02127873 0.01394994]
# Bootstrap standard deviatation
# [0.33079538 0.17475044 0.02129798 0.01396987]
# Bootstrap standard deviatation
# [0.3315062  0.17506912 0.02133745 0.01399487]
# Bootstrap standard deviatation
# [0.3319735  0.17545289 0.02135996 0.01402803]
# Bootstrap standard deviatation
# [0.33268315 0.17578914 0.02141174 0.01406192]
# Bootstrap standard deviatation
# [0.33315527 0.17598533 0.02143361 0.01406855]
# Bootstrap standard deviatation
# [0.33380498 0.17633243 0.02147801 0.01410077]
# Bootstrap standard deviatation
# [0.33440815 0.17668494 0.02150948 0.01413889]
# Bootstrap standard deviatation
# [0.33518817 0.17706544 0.02158256 0.01417347]
# Bootstrap standard deviatation
# [0.33566391 0.17727596 0.02162534 0.0141906 ]
# Bootstrap standard deviatation
# [0.33621338 0.17749274 0.02166094 0.01420587]
# Bootstrap standard deviatation
# [0.33669355 0.17771747 0.02168847 0.01422225]
# Bootstrap standard deviatation
# [0.33733947 0.17806152 0.02172771 0.01424229]
# Bootstrap standard deviatation
# [0.33777875 0.17825207 0.02176067 0.01425317]
# Bootstrap standard deviatation
# [0.33821643 0.17862529 0.02176931 0.01428858]
# Bootstrap standard deviatation
# [0.33851429 0.17890311 0.02177683 0.01431714]
# Bootstrap standard deviatation
# [0.33907598 0.17905758 0.0217902  0.01431942]
# Bootstrap standard deviatation
# [0.3398434  0.17964877 0.02184231 0.01438957]
# Bootstrap standard deviatation
# [0.34023205 0.17978532 0.02185131 0.01439132]
# Bootstrap standard deviatation
# [0.34073686 0.17995787 0.02188751 0.01440059]
# Bootstrap standard deviatation
# [0.34130902 0.18008886 0.02192237 0.0144063 ]
# Bootstrap standard deviatation
# [0.34179112 0.18039707 0.0219296  0.01442143]
# Bootstrap standard deviatation
# [0.34233226 0.18074936 0.02194331 0.01445042]
# Bootstrap standard deviatation
# [0.34282473 0.18104756 0.02198321 0.01448078]
# Bootstrap standard deviatation
# [0.3431661  0.18128471 0.02199788 0.01449853]
# Bootstrap standard deviatation
# [0.34384357 0.1817151  0.02204806 0.01454092]
# Bootstrap standard deviatation
# [0.34444832 0.1819104  0.02207968 0.01454873]
# Bootstrap standard deviatation
# [0.3449675  0.18232977 0.02210614 0.01459425]
# Bootstrap standard deviatation
# [0.34533916 0.18252681 0.02212024 0.01460691]
# Bootstrap standard deviatation
# [0.34603208 0.18270709 0.02226888 0.01461057]
# Bootstrap standard deviatation
# [0.34662613 0.18285253 0.02232628 0.01461689]
# Bootstrap standard deviatation
# [0.34717916 0.18298913 0.02235576 0.01461568]
# Bootstrap standard deviatation
# [0.34757595 0.18325574 0.02235941 0.01463009]
# Bootstrap standard deviatation
# [0.3478972  0.18346852 0.02235676 0.01463383]
# Bootstrap standard deviatation
# [0.34850802 0.18380298 0.02239937 0.01466817]
# Bootstrap standard deviatation
# [0.34937879 0.18416531 0.02248301 0.01470322]
# Bootstrap standard deviatation
# [0.3497508  0.18435382 0.02248063 0.0147045 ]
# Bootstrap standard deviatation
# [0.3502925  0.18469572 0.02251299 0.01473523]
# Bootstrap standard deviatation
# [0.35083676 0.18492281 0.02255543 0.01474992]
# Bootstrap standard deviatation
# [0.35141648 0.18525735 0.02258159 0.01477381]
# Bootstrap standard deviatation
# [0.35183044 0.18572268 0.02259782 0.01482586]
# Bootstrap standard deviatation
# [0.35240349 0.18596436 0.02265146 0.01484508]
# Bootstrap standard deviatation
# [0.35293015 0.18623809 0.02269063 0.01487359]
# Bootstrap standard deviatation
# [0.35353839 0.18657787 0.02272617 0.01490508]
# Bootstrap standard deviatation
# [0.35412155 0.18688551 0.02278581 0.01493468]
# Bootstrap standard deviatation
# [0.35462148 0.18715074 0.0228218  0.01496056]
# Bootstrap standard deviatation
# [0.35501647 0.18746662 0.02283397 0.01498534]
# Bootstrap standard deviatation
# [0.35547456 0.18767928 0.0228866  0.01499712]
# Bootstrap standard deviatation
# [0.35577704 0.18778815 0.02288878 0.01500057]
# Bootstrap standard deviatation
# [0.35622618 0.18802617 0.0228867  0.01500582]
# Bootstrap standard deviatation
# [0.35678336 0.18834727 0.02292745 0.01504047]
# Bootstrap standard deviatation
# [0.35717471 0.18858387 0.02293868 0.01505425]
# Bootstrap standard deviatation
# [0.35747586 0.18892583 0.02294989 0.01509118]
# Bootstrap standard deviatation
# [0.35800804 0.18912288 0.02301247 0.01510341]
# Bootstrap standard deviatation
# [0.35847318 0.18927093 0.02303955 0.01511042]
# Bootstrap standard deviatation
# [0.35892474 0.18943484 0.02306388 0.0151185 ]
# Bootstrap standard deviatation
# [0.35928502 0.18975565 0.02306917 0.01514426]
# Bootstrap standard deviatation
# [0.35991753 0.19006192 0.02314581 0.0151724 ]
# Bootstrap standard deviatation
# [0.36027325 0.1901737  0.02316463 0.01517973]
# Bootstrap standard deviatation
# [0.36054692 0.19032237 0.02318575 0.01519198]
# Bootstrap standard deviatation
# [0.36105385 0.19082673 0.02320144 0.01526099]
# Bootstrap standard deviatation
# [0.36157296 0.19102395 0.02325612 0.01527726]
# Bootstrap standard deviatation
# [0.36205809 0.19132403 0.02330336 0.01530386]
# Bootstrap standard deviatation
# [0.36260675 0.19178852 0.02332895 0.01537114]
# Bootstrap standard deviatation
# [0.36315233 0.19194685 0.02336675 0.01537938]
# Bootstrap standard deviatation
# [0.36388918 0.19213056 0.02344593 0.01539198]
# Bootstrap standard deviatation
# [0.36423603 0.19239428 0.02345803 0.01541748]
# Bootstrap standard deviatation
# [0.36472248 0.19267167 0.02349189 0.01543958]
# Bootstrap standard deviatation
# [0.36513827 0.19285554 0.0235273  0.01545301]
# Bootstrap standard deviatation
# [0.3654448  0.19308836 0.02353426 0.01546887]
# Bootstrap standard deviatation
# [0.36591488 0.19322105 0.02356335 0.01547066]
# Bootstrap standard deviatation
# [0.36630464 0.19339903 0.0235937  0.0154862 ]
# Bootstrap standard deviatation
# [0.3666686  0.19354148 0.02362021 0.01549535]
# Bootstrap standard deviatation
# [0.36709694 0.1938174  0.02364301 0.01553126]
# Bootstrap standard deviatation
# [0.36772425 0.19403812 0.02368945 0.01555421]
# Bootstrap standard deviatation
# [0.36817899 0.19431077 0.02371366 0.01557113]
# Bootstrap standard deviatation
# [0.36847769 0.19448067 0.02372463 0.01558739]
# Bootstrap standard deviatation
# [0.36922042 0.19473991 0.02383304 0.01561768]
# Bootstrap standard deviatation
# [0.36965505 0.19485164 0.02387944 0.01562255]
# Bootstrap standard deviatation
# [0.37000602 0.19506235 0.02389004 0.0156401 ]
# Bootstrap standard deviatation
# [0.37051147 0.19522497 0.02393677 0.01565001]
# Bootstrap standard deviatation
# [0.370885   0.19545737 0.0239649  0.01567091]
# Bootstrap standard deviatation
# [0.37123121 0.19563688 0.02397917 0.0156885 ]
# Bootstrap standard deviatation
# [0.37162125 0.19575727 0.02402435 0.01570144]
# Bootstrap standard deviatation
# [0.37207793 0.19596803 0.02405519 0.01571722]
# Bootstrap standard deviatation
# [0.37253353 0.19627388 0.02408441 0.0157474 ]
# Bootstrap standard deviatation
# [0.37304131 0.19642482 0.02412758 0.0157534 ]
# Bootstrap standard deviatation
# [0.37351795 0.19665612 0.02416862 0.01577094]
# Bootstrap standard deviatation
# [0.37373938 0.19680503 0.02417049 0.01577938]
# Bootstrap standard deviatation
# [0.37413097 0.19692483 0.02418597 0.01578237]
# Bootstrap standard deviatation
# [0.37444307 0.19715001 0.02421174 0.01579794]
# Bootstrap standard deviatation
# [0.37494522 0.1974435  0.02425024 0.0158294 ]
# Bootstrap standard deviatation
# [0.37543833 0.19759594 0.02429453 0.01583793]
# Bootstrap standard deviatation
# [0.37591126 0.19781027 0.02432757 0.01585742]
# Bootstrap standard deviatation
# [0.37619559 0.19803828 0.02434173 0.01587416]
# Bootstrap standard deviatation
# [0.37660597 0.19811483 0.02436212 0.01587423]
# Bootstrap standard deviatation
# [0.37699709 0.19830448 0.02439024 0.01588685]
# Bootstrap standard deviatation
# [0.37745059 0.19850372 0.02444934 0.01590291]
# Bootstrap standard deviatation
# [0.37797345 0.19882964 0.02450022 0.01593413]
# Bootstrap standard deviatation
# [0.37819289 0.19893605 0.02450961 0.01594041]
# Bootstrap standard deviatation
# [0.378544   0.1990729  0.02453226 0.01595006]
# Bootstrap standard deviatation
# [0.37913917 0.19938459 0.02458901 0.01598789]
# Bootstrap standard deviatation
# [0.37934511 0.19948722 0.02458723 0.01598783]
# Bootstrap standard deviatation
# [0.37957733 0.1996464  0.02459226 0.016003  ]
# Bootstrap standard deviatation
# [0.37981405 0.19982732 0.02459927 0.01601622]
# Bootstrap standard deviatation
# [0.38002713 0.19987934 0.02461783 0.01601985]
# Bootstrap standard deviatation
# [0.38046423 0.2001674  0.0246535  0.01605151]
# Bootstrap standard deviatation
# [0.38086144 0.20030921 0.02468388 0.0160606 ]
# Bootstrap standard deviatation
# [0.3812317  0.20049143 0.02471835 0.0160772 ]
# Bootstrap standard deviatation
# [0.38162268 0.20058439 0.02475308 0.01608348]
# Bootstrap standard deviatation
# [0.38194502 0.20066721 0.02476468 0.01608477]
# Bootstrap standard deviatation
# [0.3823101  0.20086101 0.02479451 0.01610141]
# Bootstrap standard deviatation
# [0.38276556 0.20101004 0.02484295 0.01611348]
# Bootstrap standard deviatation
# [0.38297185 0.20110726 0.02485404 0.01611906]
# Bootstrap standard deviatation
# [0.38328522 0.20129069 0.024885   0.01613676]
# Bootstrap standard deviatation
# [0.38354406 0.20144647 0.02489217 0.01614492]
# Bootstrap standard deviatation
# [0.38394167 0.2017328  0.02490694 0.01616353]
# Bootstrap standard deviatation
# [0.38428932 0.20179425 0.02497226 0.0161645 ]
# Bootstrap standard deviatation
# [0.38467149 0.20192714 0.02499958 0.01617377]
# Bootstrap standard deviatation
# [0.38497191 0.20194969 0.0250379  0.01617158]
# Bootstrap standard deviatation
# [0.38543423 0.20224756 0.02508342 0.01620651]
# Bootstrap standard deviatation
# [0.38569411 0.2023774  0.02509377 0.01621411]
# Bootstrap standard deviatation
# [0.38597526 0.20252122 0.02511124 0.0162221 ]
# Bootstrap standard deviatation
# [0.38631838 0.20258433 0.02512007 0.01622041]
# Bootstrap standard deviatation
# [0.38674348 0.20289415 0.02515106 0.01625262]
# Bootstrap standard deviatation
# [0.38699704 0.20294259 0.02515836 0.01625103]
# Bootstrap standard deviatation
# [0.38718893 0.20296985 0.02515281 0.01624743]
# Bootstrap standard deviatation
# [0.38749315 0.20306029 0.02517186 0.01625044]
# Bootstrap standard deviatation
# [0.38771847 0.20312826 0.0251682  0.01624772]
# Bootstrap standard deviatation
# [0.38795627 0.20330863 0.0251673  0.01626088]
# Bootstrap standard deviatation
# [0.38820873 0.20347008 0.02517405 0.01627165]
# Bootstrap standard deviatation
# [0.38841211 0.20357557 0.02518695 0.01627835]
# Bootstrap standard deviatation
# [0.38858515 0.20374016 0.02519407 0.01629471]
# Bootstrap standard deviatation
# [0.38868824 0.2038339  0.02519681 0.01630213]
# Bootstrap standard deviatation
# [0.38905593 0.20390119 0.02523392 0.01630318]
# Bootstrap standard deviatation
# [0.38937584 0.20412115 0.02525417 0.0163223 ]
# Bootstrap standard deviatation
# [0.38960718 0.20433942 0.02526126 0.01634803]
# Bootstrap standard deviatation
# [0.38992543 0.20454231 0.0252804  0.01637092]
# Bootstrap standard deviatation
# [0.39019308 0.20476562 0.02529468 0.01639085]
# Bootstrap standard deviatation
# [0.39054993 0.20485098 0.02530782 0.01639117]
# Bootstrap standard deviatation
# [0.39080299 0.20500576 0.02530781 0.01640091]
# Bootstrap standard deviatation
# [0.39111889 0.20512428 0.02531362 0.01640501]
# Bootstrap standard deviatation
# [0.39151562 0.20519056 0.02533821 0.0164062 ]
# Bootstrap standard deviatation
# [0.39168451 0.20528113 0.0253356  0.01640298]
# Bootstrap standard deviatation
# [0.39182894 0.2055049  0.02533122 0.01643986]
# Bootstrap standard deviatation
# [0.39228015 0.20581278 0.02537486 0.01647474]
# Bootstrap standard deviatation
# [0.39246066 0.20598781 0.02538214 0.01649361]
# Bootstrap standard deviatation
# [0.39274097 0.20606289 0.02541334 0.0164984 ]
# Bootstrap standard deviatation
# [0.39301409 0.20625542 0.02543923 0.01652124]
# Bootstrap standard deviatation
# [0.39333603 0.20648823 0.02546805 0.01654544]
# Bootstrap standard deviatation
# [0.39355167 0.20656376 0.02547265 0.01654416]
# Bootstrap standard deviatation
# [0.3937879  0.20667124 0.02548143 0.01654937]
# Bootstrap standard deviatation
# [0.39408435 0.20682119 0.02550231 0.01656246]
# Bootstrap standard deviatation
# [0.39428713 0.20685274 0.0255054  0.01656158]
# Bootstrap standard deviatation
# [0.39477013 0.2070375  0.02557497 0.01658081]
# Bootstrap standard deviatation
# [0.39506428 0.20729037 0.02558705 0.01660185]
# Bootstrap standard deviatation
# [0.39520865 0.20745074 0.02559295 0.01661618]
# Bootstrap standard deviatation
# [0.3953969  0.20755108 0.02560993 0.01662334]
# Bootstrap standard deviatation
# [0.39560961 0.20766197 0.02562319 0.01663011]
# Bootstrap standard deviatation
# [0.39590121 0.20776061 0.02564434 0.01663774]
# Bootstrap standard deviatation
# [0.39601294 0.20785587 0.02565097 0.01664838]
# Bootstrap standard deviatation
# [0.39623416 0.20798165 0.02567034 0.01666087]
# Bootstrap standard deviatation
# [0.39650022 0.20800848 0.02568271 0.0166587 ]
# Bootstrap standard deviatation
# [0.3967727  0.20801988 0.02568521 0.01665463]
# Bootstrap standard deviatation
# [0.39680349 0.20818337 0.02568463 0.01667262]
# Bootstrap standard deviatation
# [0.39709863 0.20833563 0.02571723 0.01668873]
# Bootstrap standard deviatation
# [0.39725274 0.20850262 0.02572643 0.01670119]
# Bootstrap standard deviatation
# [0.3974693  0.20863346 0.02572993 0.01670959]
# Bootstrap standard deviatation
# [0.39768471 0.2086984  0.02573796 0.01671296]
# Bootstrap standard deviatation
# [0.39794515 0.20880585 0.02578021 0.01672138]
# Bootstrap standard deviatation
# [0.39812397 0.20881984 0.02579129 0.01671898]
# Bootstrap standard deviatation
# [0.39839972 0.20891183 0.02579934 0.01672194]
# Bootstrap standard deviatation
# [0.39862439 0.20895546 0.02582434 0.01672304]
# Bootstrap standard deviatation
# [0.39872565 0.20912955 0.02582619 0.01674495]
# Bootstrap standard deviatation
# [0.39889328 0.20933872 0.02583557 0.01676877]
# Bootstrap standard deviatation
# [0.39904435 0.209382   0.02583339 0.01676589]
# Bootstrap standard deviatation
# [0.39928313 0.209536   0.0258352  0.01677444]
# Bootstrap standard deviatation
# [0.39946804 0.20962041 0.02584921 0.01678246]
# Bootstrap standard deviatation
# [0.3996442  0.20979707 0.02585922 0.01680109]
# Bootstrap standard deviatation
# [0.39989429 0.20991629 0.02586668 0.01680707]
# Bootstrap standard deviatation
# [0.40017291 0.20997722 0.02589275 0.0168107 ]
# Bootstrap standard deviatation
# [0.40054408 0.21019244 0.02593226 0.01683917]
# Bootstrap standard deviatation
# [0.40094222 0.21041544 0.02598493 0.01686578]
# Bootstrap standard deviatation
# [0.40123483 0.21047779 0.02601977 0.01686963]
# Bootstrap standard deviatation
# [0.40145742 0.21052533 0.02604663 0.01687265]
# Bootstrap standard deviatation
# [0.40168577 0.21060519 0.02608029 0.01688016]
# Bootstrap standard deviatation
# [0.40192786 0.21073142 0.02610018 0.01689489]
# Bootstrap standard deviatation
# [0.40211889 0.21072598 0.02613296 0.01689239]
# Bootstrap standard deviatation
# [0.4024146  0.21084059 0.02617701 0.01689868]
# Bootstrap standard deviatation
# [0.40261701 0.21093272 0.02618306 0.01690518]
# Bootstrap standard deviatation
# [0.40298555 0.21112578 0.02621498 0.01692397]
# Bootstrap standard deviatation
# [0.40324078 0.21121905 0.02622101 0.01692777]
# Bootstrap standard deviatation
# [0.40339125 0.21131197 0.02623213 0.01693485]
# Bootstrap standard deviatation
# [0.40359138 0.21134225 0.02625606 0.01693256]
# Bootstrap standard deviatation
# [0.40372589 0.2114148  0.02626795 0.01693664]
# Bootstrap standard deviatation
# [0.40388215 0.21153011 0.0262721  0.01694559]
# Bootstrap standard deviatation
# [0.40397838 0.21151299 0.02627128 0.01694087]
# Bootstrap standard deviatation
# [0.40422386 0.21171914 0.0262999  0.01696571]
# Bootstrap standard deviatation
# [0.40435847 0.21182339 0.02630753 0.01696865]
# Bootstrap standard deviatation
# [0.40443345 0.21205957 0.02630297 0.01699975]
# Bootstrap standard deviatation
# [0.4047165  0.21224841 0.02634366 0.01701944]
# Bootstrap standard deviatation
# [0.40479477 0.21236137 0.02633699 0.01702355]
# Bootstrap standard deviatation
# [0.40504742 0.21244252 0.02637222 0.01703283]
# Bootstrap standard deviatation
# [0.40519828 0.2124314  0.02639313 0.01703024]
# Bootstrap standard deviatation
# [0.40534714 0.21243851 0.02640509 0.01702875]
# Bootstrap standard deviatation
# [0.40559242 0.21247904 0.02642608 0.01703085]
# Bootstrap standard deviatation
# [0.4058122  0.2125996  0.02644418 0.01704313]
# Bootstrap standard deviatation
# [0.40590122 0.21271306 0.02644955 0.01705919]
# Bootstrap standard deviatation
# [0.40596895 0.21276018 0.0264481  0.01706387]
# Bootstrap standard deviatation
# [0.40607093 0.21279701 0.0264512  0.0170639 ]
# Bootstrap standard deviatation
# [0.40615429 0.21284496 0.02645174 0.01706539]
# Bootstrap standard deviatation
# [0.40622809 0.2128529  0.02645508 0.01706556]
# Bootstrap standard deviatation
# [0.40640498 0.21297952 0.02647535 0.0170769 ]
# Bootstrap standard deviatation
# [0.40652566 0.21303926 0.02648722 0.01708211]
# Bootstrap standard deviatation
# [0.4066549  0.21306594 0.02650989 0.01708282]
# Bootstrap standard deviatation
# [0.40678298 0.21315019 0.02650812 0.01708734]
# Bootstrap standard deviatation
# [0.40705523 0.21329011 0.02654719 0.01710102]
# Bootstrap standard deviatation
# [0.40713841 0.21341378 0.02655183 0.01712088]
# Bootstrap standard deviatation
# [0.40725415 0.21350922 0.02655158 0.01712842]
# Bootstrap standard deviatation
# [0.40731499 0.21350293 0.02654933 0.01712425]
# Bootstrap standard deviatation
# [0.4074607  0.21352693 0.0265586  0.01712241]
# Bootstrap standard deviatation
# [0.40759653 0.21364338 0.02656606 0.01713683]
# Bootstrap standard deviatation
# [0.40778886 0.21372111 0.02657742 0.01714388]
# Bootstrap standard deviatation
# [0.40787523 0.21383222 0.02658399 0.0171574 ]
# Bootstrap standard deviatation
# [0.40802341 0.21385901 0.0266049  0.01715854]
# Bootstrap standard deviatation
# [0.40814173 0.21390281 0.02661035 0.01715937]
# Bootstrap standard deviatation
# [0.40843179 0.2139596  0.02665205 0.017165  ]
# Bootstrap standard deviatation
# [0.40850286 0.21400887 0.02665409 0.01716868]
# Bootstrap standard deviatation
# [0.40869922 0.21411435 0.02667545 0.01717995]
# Bootstrap standard deviatation
# [0.40899645 0.21419941 0.02673011 0.0171881 ]
# Bootstrap standard deviatation
# [0.40912586 0.21430994 0.02674036 0.01719862]
# Bootstrap standard deviatation
# [0.40925246 0.21433031 0.02674545 0.01719849]
# Bootstrap standard deviatation
# [0.40928681 0.21437354 0.02674422 0.01720677]
# Bootstrap standard deviatation
# [0.409479   0.21446867 0.02676109 0.01721253]
# Bootstrap standard deviatation
# [0.40963725 0.21462393 0.02677936 0.01723257]
# Bootstrap standard deviatation
# [0.40971593 0.21468739 0.02677889 0.01723851]
# Bootstrap standard deviatation
# [0.40971928 0.2147593  0.02677792 0.0172475 ]
# Bootstrap standard deviatation
# [0.40986962 0.2146926  0.02680857 0.01724145]
# Bootstrap standard deviatation
# [0.4099346  0.21470415 0.02680066 0.01723606]
# Bootstrap standard deviatation
# [0.41001586 0.21487761 0.02680395 0.01726343]
# Bootstrap standard deviatation
# [0.40999401 0.21490562 0.02679451 0.01726192]
# Bootstrap standard deviatation
# [0.41024962 0.21504241 0.02685357 0.01727541]
# Bootstrap standard deviatation
# [0.41039018 0.21512288 0.02686012 0.01728076]
# Bootstrap standard deviatation
# [0.41040974 0.2151271  0.02685407 0.01728119]
# Bootstrap standard deviatation
# [0.41050472 0.21511102 0.02687955 0.01727787]
# Bootstrap standard deviatation
# [0.41054258 0.21513331 0.02687882 0.01727906]
# Bootstrap standard deviatation
# [0.41058152 0.21523341 0.0268714  0.01729011]
# Bootstrap standard deviatation
# [0.41072122 0.21528529 0.0268841  0.01729217]
# Bootstrap standard deviatation
# [0.41088131 0.21539435 0.02689368 0.01730574]
# Bootstrap standard deviatation
# [0.41093315 0.21540798 0.02689393 0.017303  ]
# Bootstrap standard deviatation
# [0.41097256 0.21549029 0.02689375 0.01731398]
# Bootstrap standard deviatation
# [0.41105044 0.2155746  0.0268971  0.01732546]
# Bootstrap standard deviatation
# [0.41133473 0.21561726 0.02693447 0.01732946]
# Bootstrap standard deviatation
# [0.41139578 0.21568847 0.02693681 0.01733513]
# Bootstrap standard deviatation
# [0.41152948 0.21573405 0.02694675 0.01733871]
# Bootstrap standard deviatation
# [0.41149517 0.21572856 0.02694057 0.01733912]
# Bootstrap standard deviatation
# [0.41152457 0.21577785 0.02695099 0.01734321]
# Bootstrap standard deviatation
# [0.4115171  0.2160627  0.02694271 0.01738768]
# Bootstrap standard deviatation
# [0.41146986 0.21607099 0.02693268 0.01738577]
# Bootstrap standard deviatation
# [0.41159422 0.21614964 0.02695207 0.01739546]
# Bootstrap standard deviatation
# [0.41171432 0.21617645 0.02697995 0.01740172]
# Bootstrap standard deviatation
# [0.411793   0.2162608  0.02698486 0.01741244]
# Bootstrap standard deviatation
# [0.4118252  0.21630452 0.02699151 0.01741719]
# Bootstrap standard deviatation
# [0.41190133 0.21626942 0.02701117 0.01741347]
# Bootstrap standard deviatation
# [0.41185035 0.21635545 0.02700114 0.01743254]
# Bootstrap standard deviatation
# [0.41192289 0.2164479  0.02701    0.01744135]
# Bootstrap standard deviatation
# [0.41199799 0.21651535 0.02702355 0.01745216]
# Bootstrap standard deviatation
# [0.4120737  0.21662656 0.02703472 0.01746976]
# Bootstrap standard deviatation
# [0.41232268 0.2166567  0.02707061 0.01747173]
# Bootstrap standard deviatation
# [0.41220835 0.21663901 0.02706001 0.01747093]
# Bootstrap standard deviatation
# [0.41231083 0.21667377 0.02707352 0.01747882]
# Bootstrap standard deviatation
# [0.41243657 0.21678124 0.02708889 0.01748951]
# Bootstrap standard deviatation
# [0.41256453 0.21694405 0.02709903 0.01751867]
# Bootstrap standard deviatation
# [0.41262576 0.21694581 0.02710783 0.01751838]
# Bootstrap standard deviatation
# [0.41263303 0.21696738 0.02711476 0.0175207 ]
# Bootstrap standard deviatation
# [0.4127014  0.2170089  0.02712909 0.01752693]
# Bootstrap standard deviatation
# [0.41279098 0.21704231 0.02714934 0.01753203]
# Bootstrap standard deviatation
# [0.4128833  0.21708277 0.02717162 0.01753626]
# Bootstrap standard deviatation
# [0.41287409 0.21714424 0.02716406 0.01754084]
# Bootstrap standard deviatation
# [0.41283491 0.21711423 0.02716205 0.01753728]
# Bootstrap standard deviatation
# [0.41291229 0.21713737 0.02717354 0.01754096]
# Bootstrap standard deviatation
# [0.41296033 0.21716206 0.02718337 0.01754179]
# Bootstrap standard deviatation
# [0.41295804 0.21718942 0.02717905 0.01754744]
# Bootstrap standard deviatation
# [0.41293714 0.21711463 0.0271765  0.01754011]
# Bootstrap standard deviatation
# [0.41288047 0.21709032 0.02717294 0.0175385 ]
# Bootstrap standard deviatation
# [0.4128542  0.21714635 0.02716706 0.0175452 ]
# Bootstrap standard deviatation
# [0.41292945 0.21710695 0.02718439 0.01754124]
# Bootstrap standard deviatation
# [0.41295795 0.21709164 0.02718727 0.0175388 ]
# Bootstrap standard deviatation
# [0.41305904 0.21707723 0.02719409 0.01753653]
# Bootstrap standard deviatation
# [0.41306517 0.21711044 0.02719205 0.01754154]
# Bootstrap standard deviatation
# [0.41305733 0.21718147 0.02718709 0.01755451]
# Bootstrap standard deviatation
# [0.41301984 0.21719589 0.02718327 0.01755518]
# Bootstrap standard deviatation
# [0.41305227 0.21718052 0.02719176 0.01755448]
# Bootstrap standard deviatation
# [0.41312315 0.21726666 0.02720505 0.01756569]
# Bootstrap standard deviatation
# [0.41309572 0.21725627 0.02720168 0.01756345]
# Bootstrap standard deviatation
# [0.41301527 0.21728205 0.02719151 0.01757123]
# Bootstrap standard deviatation
# [0.41297721 0.21747538 0.02718113 0.01761362]
# Bootstrap standard deviatation
# [0.41301139 0.21742049 0.02718823 0.01760794]
# Bootstrap standard deviatation
# [0.41319399 0.21751477 0.02722483 0.01762035]
# Bootstrap standard deviatation
# [0.41334331 0.21754479 0.02724973 0.01762259]
# Bootstrap standard deviatation
# [0.41331618 0.21746184 0.02724755 0.01761486]
# Bootstrap standard deviatation
# [0.41328835 0.21742045 0.02724409 0.01761257]
# Bootstrap standard deviatation
# [0.41332315 0.21745963 0.02724308 0.01761466]
# Bootstrap standard deviatation
# [0.41343211 0.21749696 0.02725002 0.01761803]
# Bootstrap standard deviatation
# [0.41334862 0.21752313 0.02724087 0.01762488]
# Bootstrap standard deviatation
# [0.41324291 0.21745843 0.02723158 0.01761824]
# Bootstrap standard deviatation
# [0.41320834 0.21753386 0.02722883 0.01763193]
# Bootstrap standard deviatation
# [0.41314223 0.21743993 0.02722993 0.0176241 ]
# Bootstrap standard deviatation
# [0.41311746 0.21747152 0.02723238 0.01762922]
# Bootstrap standard deviatation
# [0.41308324 0.21743208 0.02723543 0.01762508]
# Bootstrap standard deviatation
# [0.41303274 0.21737801 0.02725054 0.01762181]
# Bootstrap standard deviatation
# [0.41308659 0.21735559 0.02725627 0.01761673]
# Bootstrap standard deviatation
# [0.41302736 0.21734587 0.02725365 0.01761675]
# Bootstrap standard deviatation
# [0.41301416 0.21727274 0.02725482 0.01760877]
# Bootstrap standard deviatation
# [0.41296389 0.2172837  0.02724242 0.01760687]
# Bootstrap standard deviatation
# [0.41296757 0.21724166 0.0272383  0.01760094]
# Bootstrap standard deviatation
# [0.4129566  0.21713119 0.02724535 0.01759336]
# Bootstrap standard deviatation
# [0.41286738 0.21715346 0.02723394 0.01759533]
# Bootstrap standard deviatation
# [0.4129025  0.21719808 0.02723106 0.01760214]
# Bootstrap standard deviatation
# [0.41290013 0.21713545 0.02724508 0.0175969 ]
# Bootstrap standard deviatation
# [0.41292636 0.21714087 0.02724303 0.01759546]
# Bootstrap standard deviatation
# [0.41286936 0.21719956 0.02723692 0.01760474]
# Bootstrap standard deviatation
# [0.41283293 0.21719488 0.02723266 0.01760238]
# Bootstrap standard deviatation
# [0.41284038 0.21715376 0.02724064 0.0175979 ]
# Bootstrap standard deviatation
# [0.41276508 0.21710346 0.02723581 0.01759353]
# Bootstrap standard deviatation
# [0.41276952 0.217048   0.02724052 0.01758738]
# Bootstrap standard deviatation
# [0.41265783 0.21702485 0.0272327  0.01758679]
# Bootstrap standard deviatation
# [0.41258781 0.21695678 0.02722339 0.01757838]
# Bootstrap standard deviatation
# [0.41242163 0.21694827 0.02721079 0.01758078]
# Bootstrap standard deviatation
# [0.4123718  0.21686246 0.02720685 0.01757292]
# Bootstrap standard deviatation
# [0.41233113 0.21681282 0.02719807 0.01756519]
# Bootstrap standard deviatation
# [0.41225748 0.21677508 0.0271963  0.01756154]
# Bootstrap standard deviatation
# [0.41216431 0.21674929 0.02718516 0.01755948]
# Bootstrap standard deviatation
# [0.41212199 0.21675881 0.02717948 0.01756489]
# Bootstrap standard deviatation
# [0.41203055 0.21674335 0.02717329 0.01756565]
# Bootstrap standard deviatation
# [0.41204507 0.21671147 0.02718087 0.01756201]
# Bootstrap standard deviatation
# [0.41205729 0.21671666 0.02718273 0.01756432]
# Bootstrap standard deviatation
# [0.41195281 0.21668905 0.02716922 0.01756127]
# Bootstrap standard deviatation
# [0.41190352 0.21665769 0.0271696  0.01756031]
# Bootstrap standard deviatation
# [0.41180665 0.21662417 0.02716409 0.01755838]
# Bootstrap standard deviatation
# [0.41190726 0.21678383 0.02719504 0.01758753]
# Bootstrap standard deviatation
# [0.41194364 0.21674163 0.02720691 0.01758264]
# Bootstrap standard deviatation
# [0.41181723 0.21670777 0.0271982  0.01758295]
# Bootstrap standard deviatation
# [0.41181145 0.21662036 0.02720403 0.01757481]
# Bootstrap standard deviatation
# [0.41167166 0.21658778 0.02719031 0.01757226]
# Bootstrap standard deviatation
# [0.41159821 0.21651936 0.02719192 0.01756585]
# Bootstrap standard deviatation
# [0.41155054 0.21654808 0.02719144 0.01757464]
# Bootstrap standard deviatation
# [0.41152048 0.21652726 0.02719116 0.01757439]
# Bootstrap standard deviatation
# [0.41151428 0.21646505 0.02720907 0.01757031]
# Bootstrap standard deviatation
# [0.41131774 0.21635735 0.02719601 0.01756248]
# Bootstrap standard deviatation
# [0.41121627 0.21625215 0.0272008  0.01755453]
# Bootstrap standard deviatation
# [0.41107245 0.21617957 0.02719116 0.0175485 ]
# Bootstrap standard deviatation
# [0.41096252 0.21617787 0.0271879  0.01755555]
# Bootstrap standard deviatation
# [0.41096061 0.21614496 0.02719627 0.01755355]
# Bootstrap standard deviatation
# [0.41092102 0.21619881 0.02720262 0.01756708]
# Bootstrap standard deviatation
# [0.41082441 0.21621533 0.02719493 0.01757284]
# Bootstrap standard deviatation
# [0.4107481  0.21619345 0.02719666 0.01757598]
# Bootstrap standard deviatation
# [0.41057369 0.21612195 0.02718167 0.01756782]
# Bootstrap standard deviatation
# [0.41041253 0.21602351 0.02716753 0.01755847]
# Bootstrap standard deviatation
# [0.41032707 0.21599077 0.02715688 0.01755665]
# Bootstrap standard deviatation
# [0.41012833 0.2159322  0.02714181 0.01755144]
# Bootstrap standard deviatation
# [0.41014623 0.21592251 0.02714736 0.01755072]
# Bootstrap standard deviatation
# [0.41008322 0.21584472 0.02714924 0.01754551]
# Bootstrap standard deviatation
# [0.40992972 0.21575838 0.02714047 0.01753581]
# Bootstrap standard deviatation
# [0.40983059 0.21574066 0.02713923 0.01753717]
# Bootstrap standard deviatation
# [0.40978548 0.21567319 0.02714094 0.01752949]
# Bootstrap standard deviatation
# [0.40967948 0.21560118 0.0271308  0.01752105]
# Bootstrap standard deviatation
# [0.40965154 0.21555688 0.02713395 0.0175203 ]
# Bootstrap standard deviatation
# [0.40952683 0.2154493  0.0271334  0.01751208]
# Bootstrap standard deviatation
# [0.40941198 0.21537455 0.02713262 0.01750721]
# Bootstrap standard deviatation
# [0.40930619 0.21532264 0.02712572 0.01750412]
# Bootstrap standard deviatation
# [0.40911245 0.21527426 0.02711249 0.01750532]
# Bootstrap standard deviatation
# [0.40907624 0.21522748 0.02712495 0.01750503]
# Bootstrap standard deviatation
# [0.40899418 0.21514103 0.02712046 0.01749552]
# Bootstrap standard deviatation
# [0.40895794 0.21504844 0.02712446 0.01748735]
# Bootstrap standard deviatation
# [0.40887942 0.21507495 0.02712208 0.01749435]
# Bootstrap standard deviatation
# [0.40876329 0.21498559 0.02712708 0.01748845]
# Bootstrap standard deviatation
# [0.40860448 0.21489503 0.02712017 0.01748088]
# Bootstrap standard deviatation
# [0.40846985 0.2147825  0.02711875 0.0174714 ]
# Bootstrap standard deviatation
# [0.4083065  0.21468691 0.02711299 0.01746403]
# Bootstrap standard deviatation
# [0.40815293 0.21461948 0.02709669 0.01745447]
# Bootstrap standard deviatation
# [0.40805973 0.21458142 0.02709797 0.01745578]
# Bootstrap standard deviatation
# [0.40789667 0.2145071  0.02708798 0.01744943]
# Bootstrap standard deviatation
# [0.40777988 0.21443217 0.02709144 0.01744421]
# Bootstrap standard deviatation
# [0.40764307 0.21441156 0.02707621 0.01744789]
# Bootstrap standard deviatation
# [0.40738428 0.21440456 0.0270617  0.01745062]
# Bootstrap standard deviatation
# [0.40720884 0.21430654 0.02705395 0.01744501]
# Bootstrap standard deviatation
# [0.40709954 0.21428318 0.02704827 0.01744599]
# Bootstrap standard deviatation
# [0.40687134 0.21418721 0.02703272 0.01743571]
# Bootstrap standard deviatation
# [0.40690948 0.21411421 0.02706211 0.01743253]
# Bootstrap standard deviatation
# [0.40677198 0.21403958 0.02705442 0.01742795]
# Bootstrap standard deviatation
# [0.40664562 0.21394068 0.02705692 0.01742019]
# Bootstrap standard deviatation
# [0.40666611 0.21401446 0.0270881  0.0174352 ]
# Bootstrap standard deviatation
# [0.40648952 0.21388617 0.02708254 0.01742465]
# Bootstrap standard deviatation
# [0.40631114 0.2137729  0.02706881 0.01741418]
# Bootstrap standard deviatation
# [0.40608613 0.21369294 0.02705292 0.0174102 ]
# Bootstrap standard deviatation
# [0.40599448 0.21361639 0.02706269 0.01740673]
# Bootstrap standard deviatation
# [0.40588213 0.21358915 0.02706759 0.0174098 ]
# Bootstrap standard deviatation
# [0.40571133 0.21352189 0.02706581 0.01740544]
# Bootstrap standard deviatation
# [0.40560234 0.21346924 0.02706613 0.01740383]
# Bootstrap standard deviatation
# [0.40550218 0.21338528 0.02706953 0.01739742]
# Bootstrap standard deviatation
# [0.40540626 0.21331972 0.02706775 0.01739556]
# Bootstrap standard deviatation
# [0.40516132 0.21325717 0.02705041 0.01739636]
# Bootstrap standard deviatation
# [0.40508166 0.21326282 0.02705804 0.01740459]
# Bootstrap standard deviatation
# [0.40481947 0.21316567 0.02704039 0.01739809]
# Bootstrap standard deviatation
# [0.40478721 0.21318084 0.02704897 0.01740701]
# Bootstrap standard deviatation
# [0.40474669 0.21308942 0.02706649 0.01740197]
# Bootstrap standard deviatation
# [0.40456852 0.21295537 0.0270536  0.01739198]
# Bootstrap standard deviatation
# [0.40439368 0.21283693 0.0270541  0.01738184]
# Bootstrap standard deviatation
# [0.40418735 0.21275061 0.02703603 0.01737398]
# Bootstrap standard deviatation
# [0.40401884 0.21272982 0.027026   0.01737759]
# Bootstrap standard deviatation
# [0.40380544 0.21260485 0.0270096  0.017366  ]
# Bootstrap standard deviatation
# [0.403583   0.21247977 0.02699455 0.01735868]
# Bootstrap standard deviatation
# [0.40339875 0.21233943 0.0269889  0.01734734]
# Bootstrap standard deviatation
# [0.4032275  0.21218296 0.0269892  0.01733568]
# Bootstrap standard deviatation
# [0.40305483 0.21205294 0.02697935 0.01732477]
# Bootstrap standard deviatation
# [0.40281519 0.21192862 0.02696455 0.01731649]
# Bootstrap standard deviatation
# [0.4025446  0.21183681 0.02694591 0.0173099 ]
# Bootstrap standard deviatation
# [0.40228644 0.21171384 0.02693053 0.01729775]
# Bootstrap standard deviatation
# [0.40204307 0.21157485 0.02691719 0.01728695]
# Bootstrap standard deviatation
# [0.40184236 0.21145721 0.02691017 0.01727888]
# Bootstrap standard deviatation
# [0.40167009 0.21130876 0.02690337 0.0172676 ]
# ...
# [0.33850456 0.18015596 0.02374307 0.01529878]
# Bootstrap standard deviatation
# [0.33796638 0.17983736 0.02371241 0.01527991]
# Bootstrap standard deviatation
# [0.33740179 0.17953104 0.02368543 0.01525891]
# Bootstrap standard deviatation
# [0.33676794 0.17921104 0.02365517 0.01523627]
# Bootstrap standard deviatation
# [0.33620927 0.17891746 0.02363448 0.01521498]
# Bootstrap standard deviatation
# [0.33561963 0.17862233 0.02360576 0.01519506]
# Bootstrap standard deviatation
# [0.33499627 0.17831859 0.02357284 0.01517558]
# Bootstrap standard deviatation
# [0.33448825 0.17803934 0.02355701 0.01515898]
# Bootstrap standard deviatation
# [0.33387044 0.17771475 0.02352336 0.01513593]
# Bootstrap standard deviatation
# [0.33325437 0.17741809 0.02348794 0.0151131 ]
# Bootstrap standard deviatation
# [0.33262103 0.17710708 0.0234524  0.01509137]
# Bootstrap standard deviatation
# [0.33199955 0.17682658 0.02341969 0.01507616]
# Bootstrap standard deviatation
# [0.33149347 0.17651431 0.02341395 0.0150594 ]
# Bootstrap standard deviatation
# [0.33086366 0.17618719 0.02338662 0.01503743]
# Bootstrap standard deviatation
# [0.33021525 0.17587019 0.02335064 0.01501445]
# Bootstrap standard deviatation
# [0.32981232 0.17559719 0.02335592 0.01499847]
# Bootstrap standard deviatation
# [0.32919823 0.1752638  0.02332109 0.01497451]
# Bootstrap standard deviatation
# [0.3285253  0.17493341 0.02329309 0.0149547 ]
# Bootstrap standard deviatation
# [0.3278693  0.17465224 0.02325732 0.01493972]
# Bootstrap standard deviatation
# [0.32725565 0.17434373 0.02322932 0.01491892]
# Bootstrap standard deviatation
# [0.32662958 0.1739984  0.02319617 0.01489464]
# Bootstrap standard deviatation
# [0.32595492 0.17365999 0.0231628  0.01487167]
# Bootstrap standard deviatation
# [0.32530802 0.17331919 0.02313457 0.01484781]
# Bootstrap standard deviatation
# [0.32465148 0.1729954  0.023099   0.014826  ]
# Bootstrap standard deviatation
# [0.32398415 0.17267828 0.02306329 0.01480251]
# Bootstrap standard deviatation
# [0.32335684 0.17232316 0.02302616 0.01477913]
# Bootstrap standard deviatation
# [0.3227186  0.17201686 0.02299704 0.01476159]
# Bootstrap standard deviatation
# [0.32201445 0.1716718  0.02296691 0.01473713]
# Bootstrap standard deviatation
# [0.3213413  0.17133541 0.0229362  0.01471448]
# Bootstrap standard deviatation
# [0.32068826 0.1709982  0.02290507 0.01469169]
# Bootstrap standard deviatation
# [0.31998996 0.17063785 0.02286706 0.01466633]
# Bootstrap standard deviatation
# [0.31930171 0.1702744  0.02283256 0.01464103]
# Bootstrap standard deviatation
# [0.31860282 0.16992542 0.02279528 0.014616  ]
# Bootstrap standard deviatation
# [0.31795239 0.16959825 0.02276532 0.01459548]
# Bootstrap standard deviatation
# [0.31724762 0.16923087 0.02272843 0.01457053]
# Bootstrap standard deviatation
# [0.31653698 0.16886158 0.0226896  0.01454465]
# Bootstrap standard deviatation
# [0.31587464 0.16849569 0.02266357 0.01451955]
# Bootstrap standard deviatation
# [0.31514275 0.16812182 0.02262422 0.0144935 ]
# Bootstrap standard deviatation
# [0.31451596 0.16776737 0.02260563 0.01447066]
# Bootstrap standard deviatation
# [0.3138042  0.16751111 0.0225671  0.01446489]
# Bootstrap standard deviatation
# [0.31311183 0.16714184 0.02253351 0.01443871]
# Bootstrap standard deviatation
# [0.31241573 0.16682651 0.02249757 0.01442218]
# Bootstrap standard deviatation
# [0.3116965  0.16651213 0.02246173 0.01440696]
# Bootstrap standard deviatation
# [0.31099738 0.1661685  0.02242185 0.01438196]
# Bootstrap standard deviatation
# [0.31025645 0.16579053 0.02238896 0.01435582]
# Bootstrap standard deviatation
# [0.30949323 0.1654124  0.02234822 0.01433234]
# Bootstrap standard deviatation
# [0.30874805 0.16502703 0.02230832 0.01430541]
# Bootstrap standard deviatation
# [0.3080405  0.16468566 0.02228107 0.01428596]
# Bootstrap standard deviatation
# [0.30727538 0.16429242 0.02223979 0.01425881]
# Bootstrap standard deviatation
# [0.3065369  0.1639437  0.022205   0.01423709]
# Bootstrap standard deviatation
# [0.30575617 0.16357051 0.02216415 0.01421121]
# Bootstrap standard deviatation
# [0.30497147 0.16318591 0.02212315 0.01418448]
# Bootstrap standard deviatation
# [0.30421609 0.16278563 0.02209063 0.0141569 ]
# Bootstrap standard deviatation
# [0.30353066 0.16238358 0.02206563 0.01412906]
# Bootstrap standard deviatation
# [0.30274442 0.16198033 0.02202513 0.01410265]
# Bootstrap standard deviatation
# [0.30195546 0.1615958  0.02198315 0.01407784]
# Bootstrap standard deviatation
# [0.3011536  0.16121366 0.02194895 0.01405056]
# Bootstrap standard deviatation
# [0.30036442 0.1608043  0.02191248 0.01402226]
# Bootstrap standard deviatation
# [0.29955783 0.16042304 0.02186953 0.01399917]
# Bootstrap standard deviatation
# [0.29879991 0.16002157 0.02182641 0.01397057]
# Bootstrap standard deviatation
# [0.29802702 0.15965985 0.02178316 0.01394509]
# Bootstrap standard deviatation
# [0.29723369 0.15927848 0.02174262 0.0139195 ]
# Bootstrap standard deviatation
# [0.29647441 0.15890324 0.02171109 0.01389649]
# Bootstrap standard deviatation
# [0.2956929  0.15848052 0.02167619 0.01386739]
# Bootstrap standard deviatation
# [0.29486758 0.15805678 0.02164577 0.01383826]
# Bootstrap standard deviatation
# [0.29413187 0.15775822 0.02160763 0.01383507]
# Bootstrap standard deviatation
# [0.29340658 0.15735083 0.02158494 0.0138073 ]
# Bootstrap standard deviatation
# [0.29257092 0.15694271 0.02154431 0.01378151]
# Bootstrap standard deviatation
# [0.29178493 0.15654192 0.02150169 0.01375351]
# Bootstrap standard deviatation
# [0.29094244 0.15611321 0.02145666 0.01372366]
# Bootstrap standard deviatation
# [0.29007736 0.1556916  0.0214203  0.01369409]
# Bootstrap standard deviatation
# [0.28921003 0.15525331 0.02137543 0.01366404]
# Bootstrap standard deviatation
# [0.28834591 0.15481936 0.02133006 0.01363904]
# Bootstrap standard deviatation
# [0.28754143 0.15444262 0.02129799 0.01361773]
# Bootstrap standard deviatation
# [0.28670369 0.15406002 0.02125438 0.01360055]
# Bootstrap standard deviatation
# [0.28584975 0.15363983 0.0212087  0.01357385]
# Bootstrap standard deviatation
# [0.2849553  0.15323963 0.02117239 0.0135487 ]
# Bootstrap standard deviatation
# [0.28408683 0.15283046 0.0211268  0.01352488]
# Bootstrap standard deviatation
# [0.28320261 0.15237815 0.0210859  0.01349494]
# Bootstrap standard deviatation
# [0.28232869 0.15193737 0.02103966 0.01346431]
# Bootstrap standard deviatation
# [0.28141525 0.15148838 0.0209931  0.01343417]
# Bootstrap standard deviatation
# [0.28049885 0.15102614 0.02095282 0.0134028 ]
# Bootstrap standard deviatation
# [0.2795932  0.15056034 0.02091535 0.0133712 ]
# Bootstrap standard deviatation
# [0.27869818 0.15009219 0.02086772 0.01334099]
# Bootstrap standard deviatation
# [0.27779812 0.14968409 0.02082411 0.01331979]
# Bootstrap standard deviatation
# [0.27686182 0.14923089 0.02077616 0.01328929]
# Bootstrap standard deviatation
# [0.27596614 0.14877879 0.02073492 0.01326166]
# Bootstrap standard deviatation
# [0.27506678 0.14831851 0.02069912 0.0132309 ]
# Bootstrap standard deviatation
# [0.27415172 0.14787584 0.02066425 0.0132048 ]
# Bootstrap standard deviatation
# [0.27329647 0.1474529  0.02064147 0.01318182]
# Bootstrap standard deviatation
# [0.2723715  0.1470522  0.02059311 0.01316574]
# Bootstrap standard deviatation
# [0.27141247 0.14658886 0.02054442 0.01313675]
# Bootstrap standard deviatation
# [0.2704405  0.14610183 0.02049557 0.01310399]
# Bootstrap standard deviatation
# [0.2695434  0.14562003 0.02047104 0.01307146]
# Bootstrap standard deviatation
# [0.26855409 0.14512335 0.02042092 0.0130381 ]
# Bootstrap standard deviatation
# [0.26758402 0.1446567  0.02037287 0.01301331]
# Bootstrap standard deviatation
# [0.26658313 0.14416871 0.02032412 0.01298324]
# Bootstrap standard deviatation
# [0.26560189 0.14367312 0.02027746 0.01295023]
# Bootstrap standard deviatation
# [0.26467466 0.14317992 0.02023761 0.0129167 ]
# Bootstrap standard deviatation
# [0.26368034 0.14268729 0.02018668 0.01288441]
# Bootstrap standard deviatation
# [0.26266435 0.14217421 0.02013528 0.01285139]
# Bootstrap standard deviatation
# [0.26164634 0.14165815 0.02008414 0.01281766]
# Bootstrap standard deviatation
# [0.26060837 0.14114028 0.02003307 0.01278314]
# Bootstrap standard deviatation
# [0.2595705  0.1406188  0.01998315 0.01274861]
# Bootstrap standard deviatation
# [0.25861856 0.1401428  0.01994127 0.01272357]
# Bootstrap standard deviatation
# [0.25756277 0.13961633 0.01989402 0.0126897 ]
# Bootstrap standard deviatation
# [0.25652549 0.13908951 0.01984157 0.01265453]
# Bootstrap standard deviatation
# [0.25548944 0.13860171 0.019789   0.01262256]
# Bootstrap standard deviatation
# [0.25441792 0.13806559 0.01973554 0.01258703]
# Bootstrap standard deviatation
# [0.25336342 0.13752525 0.01968726 0.01255146]
# Bootstrap standard deviatation
# [0.25231729 0.13698836 0.01963637 0.0125156 ]
# Bootstrap standard deviatation
# [0.25126252 0.13644803 0.01959379 0.01247984]
# Bootstrap standard deviatation
# [0.25018919 0.13592759 0.01954037 0.012454  ]
# Bootstrap standard deviatation
# [0.249076   0.13537496 0.01948596 0.01241876]
# Bootstrap standard deviatation
# [0.24798378 0.13481795 0.01944137 0.01238222]
# Bootstrap standard deviatation
# [0.24687583 0.1342596  0.01938857 0.01234587]
# Bootstrap standard deviatation
# [0.24575296 0.13369983 0.01933892 0.01231042]
# Bootstrap standard deviatation
# [0.24462209 0.13313258 0.01928643 0.01227365]
# Bootstrap standard deviatation
# [0.24347325 0.13257258 0.01923121 0.01223811]
# Bootstrap standard deviatation
# [0.24236165 0.13200932 0.01918513 0.01220156]
# Bootstrap standard deviatation
# [0.24122279 0.13146809 0.01913002 0.01217031]
# Bootstrap standard deviatation
# [0.24005036 0.13088502 0.01907394 0.01213277]
# Bootstrap standard deviatation
# [0.23894664 0.13029899 0.01901822 0.01209971]
# Bootstrap standard deviatation
# [0.23775916 0.12970833 0.01896221 0.01206354]
# Bootstrap standard deviatation
# [0.23656443 0.12912404 0.01890748 0.01202563]
# Bootstrap standard deviatation
# [0.23541615 0.12859446 0.01885564 0.01200069]
# Bootstrap standard deviatation
# [0.23420175 0.12799722 0.01880159 0.01196457]
# Bootstrap standard deviatation
# [0.23297938 0.12741531 0.01874283 0.01193045]
# Bootstrap standard deviatation
# [0.23174803 0.12682409 0.01868423 0.01189374]
# Bootstrap standard deviatation
# [0.23051299 0.12623864 0.01862798 0.01185872]
# Bootstrap standard deviatation
# [0.22926523 0.12561906 0.01857069 0.01181905]
# Bootstrap standard deviatation
# [0.22800213 0.12499584 0.01851466 0.01178024]
# Bootstrap standard deviatation
# [0.22676296 0.12437178 0.01845975 0.01174125]
# Bootstrap standard deviatation
# [0.22548627 0.12373901 0.01839938 0.01170091]
# Bootstrap standard deviatation
# [0.22419407 0.12310354 0.01833957 0.01166142]
# Bootstrap standard deviatation
# [0.22289173 0.12248026 0.01828079 0.01162206]
# Bootstrap standard deviatation
# [0.22157805 0.12183518 0.01821939 0.01158119]
# Bootstrap standard deviatation
# [0.22026429 0.12119648 0.01817122 0.01154172]
# Bootstrap standard deviatation
# [0.21894355 0.12061387 0.0181288  0.01152508]
# Bootstrap standard deviatation
# [0.21760138 0.11996129 0.01806759 0.01148345]
# Bootstrap standard deviatation
# [0.21626855 0.1192962  0.01800638 0.01144162]
# Bootstrap standard deviatation
# [0.21491648 0.11863537 0.01794505 0.01140133]
# Bootstrap standard deviatation
# [0.21355821 0.11798416 0.01788468 0.01136271]
# Bootstrap standard deviatation
# [0.21216798 0.11730423 0.01782082 0.01132046]
# Bootstrap standard deviatation
# [0.21076949 0.11663701 0.0177566  0.01127879]
# Bootstrap standard deviatation
# [0.20936104 0.11596588 0.01769369 0.01123874]
# Bootstrap standard deviatation
# [0.20793374 0.11527097 0.01762896 0.01119669]
# Bootstrap standard deviatation
# [0.20649538 0.11458002 0.01756361 0.01115387]
# Bootstrap standard deviatation
# [0.20507233 0.11397937 0.01749823 0.01114411]
# Bootstrap standard deviatation
# [0.20361103 0.11326839 0.01743224 0.01110041]
# Bootstrap standard deviatation
# [0.20214908 0.11257407 0.01737057 0.01105981]
# Bootstrap standard deviatation
# [0.20065414 0.11188951 0.01731288 0.0110298 ]
# Bootstrap standard deviatation
# [0.1991703  0.11115962 0.01724814 0.01098524]
# Bootstrap standard deviatation
# [0.19764622 0.110432   0.01718052 0.01094227]
# Bootstrap standard deviatation
# [0.19614474 0.10968868 0.01712286 0.01089723]
# Bootstrap standard deviatation
# [0.19462357 0.10894421 0.01706569 0.01085352]
# Bootstrap standard deviatation
# [0.19305919 0.10823272 0.01699721 0.01081953]
# Bootstrap standard deviatation
# [0.19151362 0.10747493 0.01695684 0.01077806]
# Bootstrap standard deviatation
# [0.18994003 0.1067182  0.01689387 0.0107361 ]
# Bootstrap standard deviatation
# [0.18832191 0.1059688  0.01682458 0.01069417]
# Bootstrap standard deviatation
# [0.18669445 0.10519723 0.01675446 0.01064912]
# Bootstrap standard deviatation
# [0.185082   0.1044096  0.01668524 0.01060236]
# Bootstrap standard deviatation
# [0.18345743 0.10365329 0.01661971 0.01056201]
# Bootstrap standard deviatation
# [0.18180952 0.10286663 0.0165501  0.01051641]
# Bootstrap standard deviatation
# [0.18009879 0.10209087 0.01647809 0.01048615]
# Bootstrap standard deviatation
# [0.17837045 0.10128649 0.01640766 0.01044343]
# Bootstrap standard deviatation
# [0.17662066 0.10045742 0.01633537 0.01039639]
# Bootstrap standard deviatation
# [0.17489341 0.09961705 0.01627364 0.01034819]
# Bootstrap standard deviatation
# [0.17312372 0.09876924 0.01620098 0.01029929]
# Bootstrap standard deviatation
# [0.17131485 0.09792768 0.01612964 0.01025605]
# Bootstrap standard deviatation
# [0.16948298 0.09706312 0.01605583 0.01020661]
# Bootstrap standard deviatation
# [0.16762922 0.09628401 0.01599053 0.01019076]
# Bootstrap standard deviatation
# [0.1657536  0.09540167 0.01591625 0.01014121]
# Bootstrap standard deviatation
# [0.16387223 0.09450667 0.01584159 0.01009094]
# Bootstrap standard deviatation
# [0.16193629 0.09364393 0.01576481 0.0100577 ]
# Bootstrap standard deviatation
# [0.15997079 0.09275565 0.01569424 0.01000915]
# Bootstrap standard deviatation
# [0.15798362 0.09184428 0.01561992 0.00996405]
# Bootstrap standard deviatation
# [0.1559616  0.09091613 0.0155436  0.00991272]
# Bootstrap standard deviatation
# [0.15392451 0.08996916 0.01547036 0.00986079]
# Bootstrap standard deviatation
# [0.15183843 0.08900875 0.01539303 0.00980839]
# Bootstrap standard deviatation
# [0.14972816 0.08804788 0.01531627 0.00976099]
# Bootstrap standard deviatation
# [0.14757515 0.08706213 0.01523723 0.00970783]
# Bootstrap standard deviatation
# [0.14540371 0.08606268 0.01516085 0.00965449]
# Bootstrap standard deviatation
# [0.14317575 0.0851019  0.01507917 0.00961106]
# Bootstrap standard deviatation
# [0.14090977 0.08408258 0.01500057 0.00955668]
# Bootstrap standard deviatation
# [0.13860257 0.08305346 0.01491953 0.00950345]
# Bootstrap standard deviatation
# [0.13624884 0.08202829 0.01483643 0.00945281]
# Bootstrap standard deviatation
# [0.13386427 0.08097688 0.01475555 0.00939914]
# Bootstrap standard deviatation
# [0.13141651 0.07988788 0.01467287 0.00934305]
# Bootstrap standard deviatation
# [0.1289161  0.07878671 0.01459128 0.00928659]
# Bootstrap standard deviatation
# [0.12636608 0.07767613 0.0145056  0.00923085]
# Bootstrap standard deviatation
# [0.12383823 0.07657883 0.01443002 0.00917838]
# Bootstrap standard deviatation
# [0.12119647 0.07541888 0.0143496  0.00912053]
# Bootstrap standard deviatation
# [0.11845712 0.07423691 0.01426208 0.00906221]
# Bootstrap standard deviatation
# [0.11568893 0.07305904 0.01419195 0.00900581]
# Bootstrap standard deviatation
# [0.11290985 0.071868   0.01412642 0.00895149]
# Bootstrap standard deviatation
# [0.10994433 0.07064214 0.01403661 0.00889683]
# Bootstrap standard deviatation
# [0.10694468 0.06937931 0.0139457  0.00883682]
# Bootstrap standard deviatation
# [0.10383792 0.06814111 0.0138848  0.00878488]
# Bootstrap standard deviatation
# [0.10059197 0.06682294 0.01381696 0.00872574]
# Bootstrap standard deviatation
# [0.09722648 0.06550827 0.01372779 0.00867102]
# Bootstrap standard deviatation
# [0.09373355 0.06413724 0.01363376 0.00861113]
# Bootstrap standard deviatation
# [0.09009888 0.06272022 0.01354006 0.00855168]
# Bootstrap standard deviatation
# [0.08631279 0.06134425 0.01344494 0.00849581]
# Bootstrap standard deviatation
# [0.08242419 0.05986765 0.01336399 0.00843436]
# Bootstrap standard deviatation
# [0.07824449 0.05834232 0.01326651 0.00837064]
# Bootstrap standard deviatation
# [0.07380892 0.05680888 0.01317153 0.00830899]
# Bootstrap standard deviatation
# [0.06908908 0.05518492 0.01308186 0.00824455]

# %% [markdown]
# ### Practicalities
#
# Deliver your solutions (a single Jupyter notebook, with the analytical parts
# either typeset in Markdown/LaTeX or as a scanned handwritten note) in Canvas
# before **Friday September 4 at midnight**. Collaboration is encouraged — list
# your collaborators.
